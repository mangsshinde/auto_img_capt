# %% [markdown]
# <a href="https://colab.research.google.com/github/mangsshinde/auto_img_capt/blob/master/Image_Caption_Keras_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
# !pip install tensorflow==2.8
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.8
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.0%2Bzzzcolab20220506162203-cp37-cp37m-linux_x86_64.whl (668.3 MB)
#      |████████████████████████████████| 668.3 MB 17 kB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.26.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.14.1)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 6.8 MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.16.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 71.5 MB/s
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.12)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.21.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (64.0.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.7.0)
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 65.8 MB/s
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.47.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.19.4)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (4.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (14.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2022.6.15)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.7/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.1)
# Installing collected packages: tf-estimator-nightly, tensorboard, keras, tensorflow
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.1
#     Uninstalling tensorflow-2.9.1:
#       Successfully uninstalled tensorflow-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-gpu 2.2.0 requires gast==0.3.3, but you have gast 0.4.0 which is incompatible.
# tensorflow-gpu 2.2.0 requires h5py<2.11.0,>=2.10.0, but you have h5py 3.7.0 which is incompatible.
# tensorflow-gpu 2.2.0 requires tensorboard<2.3.0,>=2.2.0, but you have tensorboard 2.8.0 which is incompatible.
# tensorflow-gpu 2.2.0 requires tensorflow-estimator<2.3.0,>=2.2.0, but you have tensorflow-estimator 2.9.0 which is incompatible.
# Successfully installed keras-2.8.0 tensorboard-2.8.0 tensorflow-2.8.0+zzzcolab20220506162203 tf-estimator-nightly-2.8.0.dev2021122109

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 17 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 11s (39.0 MB/s)
# (Reading database ... 155680 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155658 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb ...
# Unpacking libcudnn8 (8.1.0.77-1+cuda11.2) over (8.0.5.39-1+cuda11.1) ...
# Setting up libcudnn8 (8.1.0.77-1+cuda11.2) ...

# %%
# !pip install tensorflow-gpu==2.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==2.2.0
#   Downloading tensorflow_gpu-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2 MB)
#      |████████████████████████████████| 516.2 MB 4.5 kB/s
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.1.2)
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
#      |████████████████████████████████| 26.1 MB 1.4 MB/s
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      |████████████████████████████████| 454 kB 62.4 MB/s
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.6.3)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 52.3 MB/s
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 48.3 MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (0.37.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (3.17.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.47.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.2.0) (3.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (57.4.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.2.0)
# Installing collected packages: tensorflow-estimator, tensorboard, scipy, h5py, gast, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220719082949 requires tensorboard<2.9,>=2.8, but you have tensorboard 2.2.2 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220719082949 requires tensorflow-estimator<2.9,>=2.8, but you have tensorflow-estimator 2.2.0 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.4.1 which is incompatible.
# jaxlib 0.3.14+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# jax 0.3.14 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# Successfully installed gast-0.3.3 h5py-2.10.0 scipy-1.4.1 tensorboard-2.2.2 tensorflow-estimator-2.2.0 tensorflow-gpu-2.2.0

# %%
# !pip uninstall keras
# Out:
# Found existing installation: keras 2.8.0
# Uninstalling keras-2.8.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/keras-2.8.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/keras/*
# Proceed (y/n)? y
#   Successfully uninstalled keras-2.8.0

# %%
# !pip install tensorflow --upgrade --force-reinstall
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 6.4 kB/s
# Collecting numpy>=1.20
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 52.7 MB/s
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 48.6 MB/s
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 4.8 MB/s
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 64.7 MB/s
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 7.2 MB/s
# Collecting packaging
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 6.9 MB/s
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 53.3 MB/s
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.47.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 50.9 MB/s
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 45.8 MB/s
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.6 MB/s
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 58.3 MB/s
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting six>=1.12.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 62.3 MB/s
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.0 MB/s
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 78.8 MB/s
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 49.0 MB/s
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting setuptools
#   Downloading setuptools-64.0.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 18.9 MB/s
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.0 MB/s
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 42.4 MB/s
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.9 MB/s
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 56.5 MB/s
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 70.0 MB/s
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.10.0-py2.py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 71.2 MB/s
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 70.1 MB/s
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.6 MB/s
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 8.2 MB/s
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.6.15-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 76.1 MB/s
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 80.2 MB/s
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 61.5 MB/s
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 7.6 MB/s
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=9c50981af6cbce9f49a1fdfa1f2556c74ae01cbca5d67ea71cbfe6a028bc0a0b
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built termcolor
# Installing collected packages: urllib3, pyasn1, idna, charset-normalizer, certifi, zipp, typing-extensions, six, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, MarkupSafe, importlib-metadata, google-auth, wheel, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, setuptools, pyparsing, protobuf, numpy, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, packaging, opt-einsum, libclang, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.4.8
#     Uninstalling pyasn1-0.4.8:
#       Successfully uninstalled pyasn1-0.4.8
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.1.0
#     Uninstalling charset-normalizer-2.1.0:
#       Successfully uninstalled charset-normalizer-2.1.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.6.15
#     Uninstalling certifi-2022.6.15:
#       Successfully uninstalled certifi-2022.6.15
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.8.1
#     Uninstalling zipp-3.8.1:
#       Successfully uninstalled zipp-3.8.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1-modules 0.2.8
#     Uninstalling pyasn1-modules-0.2.8:
#       Successfully uninstalled pyasn1-modules-0.2.8
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.0
#     Uninstalling oauthlib-3.2.0:
#       Successfully uninstalled oauthlib-3.2.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.4
#     Uninstalling cachetools-4.2.4:
#       Successfully uninstalled cachetools-4.2.4
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.1
#     Uninstalling requests-oauthlib-1.3.1:
#       Successfully uninstalled requests-oauthlib-1.3.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.12.0
#     Uninstalling importlib-metadata-4.12.0:
#       Successfully uninstalled importlib-metadata-4.12.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.35.0
#     Uninstalling google-auth-1.35.0:
#       Successfully uninstalled google-auth-1.35.0
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.1
#     Uninstalling wheel-0.37.1:
#       Successfully uninstalled wheel-0.37.1
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: tensorboard-plugin-wit
#     Found existing installation: tensorboard-plugin-wit 1.8.1
#     Uninstalling tensorboard-plugin-wit-1.8.1:
#       Successfully uninstalled tensorboard-plugin-wit-1.8.1
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.4.1
#     Uninstalling Markdown-3.4.1:
#       Successfully uninstalled Markdown-3.4.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.47.0
#     Uninstalling grpcio-1.47.0:
#       Successfully uninstalled grpcio-1.47.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.2.0
#     Uninstalling absl-py-1.2.0:
#       Successfully uninstalled absl-py-1.2.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 1.1.0
#     Uninstalling termcolor-1.1.0:
#       Successfully uninstalled termcolor-1.1.0
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.26.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.26.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.26.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt-einsum 3.3.0
#     Uninstalling opt-einsum-3.3.0:
#       Successfully uninstalled opt-einsum-3.3.0
#   Attempting uninstall: libclang
#     Found existing installation: libclang 14.0.6
#     Uninstalling libclang-14.0.6:
#       Successfully uninstalled libclang-14.0.6
#   Attempting uninstall: keras-preprocessing
#     Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: google-pasta
#     Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: astunparse
#     Found existing installation: astunparse 1.6.3
#     Uninstalling astunparse-1.6.3:
#       Successfully uninstalled astunparse-1.6.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
#     Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.1.0 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.3.0 which is incompatible.
# tensorflow-gpu 2.2.0 requires gast==0.3.3, but you have gast 0.4.0 which is incompatible.
# tensorflow-gpu 2.2.0 requires h5py<2.11.0,>=2.10.0, but you have h5py 3.7.0 which is incompatible.
# tensorflow-gpu 2.2.0 requires tensorboard<2.3.0,>=2.2.0, but you have tensorboard 2.9.1 which is incompatible.
# tensorflow-gpu 2.2.0 requires tensorflow-estimator<2.3.0,>=2.2.0, but you have tensorflow-estimator 2.9.0 which is incompatible.
# spacy 3.4.1 requires typing-extensions<4.2.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.3.0 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.4.1 which is incompatible.
# jaxlib 0.3.14+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# jax 0.3.14 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# google-api-core 1.31.6 requires google-auth<2.0dev,>=1.25.0, but you have google-auth 2.10.0 which is incompatible.
# flask 1.1.4 requires Werkzeug<2.0,>=0.15, but you have werkzeug 2.2.2 which is incompatible.
# Successfully installed MarkupSafe-2.1.1 absl-py-1.2.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.6.15 charset-normalizer-2.1.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.10.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.47.0 h5py-3.7.0 idna-3.3 importlib-metadata-4.12.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 numpy-1.21.6 oauthlib-3.2.0 opt-einsum-3.3.0 packaging-21.3 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 setuptools-64.0.1 six-1.16.0 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0 typing-extensions-4.3.0 urllib3-1.26.11 werkzeug-2.2.2 wheel-0.37.1 wrapt-1.14.1 zipp-3.8.1

# %%
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np
from numpy import array
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import string
import os
from PIL import Image
import glob
from pickle import dump, load
from time import time
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, TimeDistributed, Dense, RepeatVector,\
                         Activation, Flatten, Reshape, concatenate, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import add
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras import Input, layers
from tensorflow.keras import optimizers
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from os import listdir
from collections import Counter

# %% [markdown]
# # Loading dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/Flickr8k_Dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/Flicker8k_Dataset/._342872408_04a2832a1b.jpg
#   inflating: Flicker8k_Dataset/3429142249_d09a32e291.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429142249_d09a32e291.jpg
#   inflating: Flicker8k_Dataset/3429194423_98e911a101.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429194423_98e911a101.jpg
#   inflating: Flicker8k_Dataset/3429351222_17ae744daf.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429351222_17ae744daf.jpg
#   inflating: Flicker8k_Dataset/3429351964_531de1bf16.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429351964_531de1bf16.jpg
#   inflating: Flicker8k_Dataset/3429391520_930b153f94.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429391520_930b153f94.jpg
#   inflating: Flicker8k_Dataset/3429465163_fb8ac7ce7f.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429465163_fb8ac7ce7f.jpg
#   inflating: Flicker8k_Dataset/3429581486_4556471d1a.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429581486_4556471d1a.jpg
#   inflating: Flicker8k_Dataset/3429641260_2f035c1813.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429641260_2f035c1813.jpg
#   inflating: Flicker8k_Dataset/3429956016_3c7e3096c2.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3429956016_3c7e3096c2.jpg
#   inflating: Flicker8k_Dataset/3430100177_5864bf1e73.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3430100177_5864bf1e73.jpg
#   inflating: Flicker8k_Dataset/3430287726_94a1825bbf.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3430287726_94a1825bbf.jpg
#   inflating: Flicker8k_Dataset/3430526230_234b3550f6.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3430526230_234b3550f6.jpg
#   inflating: Flicker8k_Dataset/3430607596_7e4f74e3ff.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3430607596_7e4f74e3ff.jpg
#   inflating: Flicker8k_Dataset/343073813_df822aceac.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._343073813_df822aceac.jpg
#   inflating: Flicker8k_Dataset/3430779304_43a2146f4b.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._3430779304_43a2146f4b.jpg
#   inflating: Flicker8k_Dataset/3430782104_34da558eba.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._
k_Dataset/977856234_0d9caee7b2.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._977856234_0d9caee7b2.jpg
#   inflating: Flicker8k_Dataset/978580450_e862715aba.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._978580450_e862715aba.jpg
#   inflating: Flicker8k_Dataset/979201222_75b6456d34.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._979201222_75b6456d34.jpg
#   inflating: Flicker8k_Dataset/979383193_0a542a059d.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._979383193_0a542a059d.jpg
#   inflating: Flicker8k_Dataset/98377566_e4674d1ebd.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._98377566_e4674d1ebd.jpg
#   inflating: Flicker8k_Dataset/985067019_705fe4a4cc.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._985067019_705fe4a4cc.jpg
#   inflating: Flicker8k_Dataset/987907964_5a06a63609.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._987907964_5a06a63609.jpg
#   inflating: Flicker8k_Dataset/989754491_7e53fb4586.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._989754491_7e53fb4586.jpg
#   inflating: Flicker8k_Dataset/989851184_9ef368e520.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._989851184_9ef368e520.jpg
#   inflating: Flicker8k_Dataset/990890291_afc72be141.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._990890291_afc72be141.jpg
#   inflating: Flicker8k_Dataset/99171998_7cc800ceef.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._99171998_7cc800ceef.jpg
#   inflating: Flicker8k_Dataset/99679241_adc853a5c0.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._99679241_adc853a5c0.jpg
#   inflating: Flicker8k_Dataset/997338199_7343367d7f.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._997338199_7343367d7f.jpg
#   inflating: Flicker8k_Dataset/997722733_0cb5439472.jpg
#   inflating: __MACOSX/Flicker8k_Dataset/._997722733_0cb5439472.jpg
#   inflating: __MACOSX/._Flicker8k_Dataset

# %%
# !unzip /content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/Flickr8k_text.zip
# Out:
# Archive:  /content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/Flickr8k_text.zip
#   inflating: CrowdFlowerAnnotations.txt
#   inflating: ExpertAnnotations.txt
#   inflating: Flickr8k.lemma.token.txt
#   inflating: __MACOSX/._Flickr8k.lemma.token.txt
#   inflating: Flickr8k.token.txt
#   inflating: Flickr_8k.devImages.txt
#   inflating: Flickr_8k.testImages.txt
#   inflating: Flickr_8k.trainImages.txt
#   inflating: readme.txt

# %% [markdown]
# # Load Captions

# %%
def load_doc(filename):
    with open(filename) as file:
        text = file.readlines()
        return text

filename = "/content/Flickr8k.token.txt"
text = load_doc(filename)
for line in text[:10]:
    print(line,end='')

# every image has 5 captions
# Out:
# 1000268201_693b08cb0e.jpg#0	A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg#1	A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg#2	A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg#3	A little girl climbing the stairs to her playhouse .
# 1000268201_693b08cb0e.jpg#4	A little girl in a pink dress going into a wooden cabin .
# 1001773457_577c3a7d70.jpg#0	A black dog and a spotted dog are fighting
# 1001773457_577c3a7d70.jpg#1	A black dog and a tri-colored dog playing with each other on the road .
# 1001773457_577c3a7d70.jpg#2	A black dog and a white dog with brown spots are staring at each other in the street .
# 1001773457_577c3a7d70.jpg#3	Two dogs of different breeds looking at each other on the road .
# 1001773457_577c3a7d70.jpg#4	Two dogs on pavement moving toward each other .

# %% [markdown]
# # Mapping image with captions

# %%
def image_to_captions(text):
    hash_map = {}
    for line in text:
        token = line.split()
        image_id = token[0].split('.')[0] # separating with '.' to extract image id (removing .jpg)
        image_caption = ' '.join(token[1: ])
        
        if(image_id not in hash_map):
            hash_map[image_id] = [image_caption]
        else:
            hash_map[image_id].append(image_caption)
        
    return hash_map
        

map_img_to_captions = image_to_captions(text)
print(*map_img_to_captions['1000268201_693b08cb0e'],sep='\n')
# Out:
# A child in a pink dress is climbing up a set of stairs in an entry way .
# A girl going into a wooden building .
# A little girl climbing into a wooden playhouse .
# A little girl climbing the stairs to her playhouse .
# A little girl in a pink dress going into a wooden cabin .

# %% [markdown]
# # Data Preprocessing

# %%
def preprocess(map_img_to_captions):
    preprocessed_captions = []
    for key in map_img_to_captions.keys():
        for idx in range(len(map_img_to_captions[key])):
            tokens = map_img_to_captions[key][idx].split()
            tokens = [token.lower() for token in tokens if len(token)>1 if token.isalpha()]
            map_img_to_captions[key][idx] = ' '.join(tokens)
            
    return map_img_to_captions


preprocessed_map = preprocess(map_img_to_captions)
preprocessed_map['1000268201_693b08cb0e']
# Out:
# ['child in pink dress is climbing up set of stairs in an entry way',
#  'girl going into wooden building',
#  'little girl climbing into wooden playhouse',
#  'little girl climbing the stairs to her playhouse',
#  'little girl in pink dress going into wooden cabin']

# %% [markdown]
# # Create vocabulary from captions

# %%
def create_vocabulary(preprocessed_map):
    vocabulary = set()
    for img_captions in preprocessed_map.values(): # list of 5 captions for each image
        for caption in img_captions:
            for token in caption.split():
                vocabulary.add(token)    
    return vocabulary


vocabulary = create_vocabulary(preprocessed_map)
print('Vocabulary size',len(vocabulary))
# Out:
# Vocabulary size 8357

# %% [markdown]
# # Saving image id and preprocessed captions to new text file

# %%
def save_captions(preprocessed_map,filename):
    data = []
    for image_id,image_captions in preprocessed_map.items():
        for caption in image_captions:
            data.append(image_id + ' ' + caption + '\n')
            
    with open(filename,'w') as file:
        for line in data:
            file.write(line)

save_captions(preprocessed_map,'preprocessed_captions.txt')

# %% [markdown]
# # Load images (image name) of Train & Test Data

# %%
def img_id_train(filename):
    with open(filename) as file:
        data = file.readlines()
        train_img_name = []
        for img_id in data:
            train_img_name.append(img_id.split('.')[0])
    return train_img_name    

train_img_name = img_id_train('/content/Flickr_8k.trainImages.txt')
test_img_name  = img_id_train('/content/Flickr_8k.testImages.txt')
print(*train_img_name[:5],sep='\n')
print('\nNumber of images in train data',len(train_img_name))
print('\nNumber of images in train data',len(test_img_name))
# Out:
# 2513260012_03d33305cf
# 2903617548_d3e38d7f88
# 3338291921_fe7ae0c8f8
# 488416045_1c6d903fe0
# 2644326817_8f45080b87
#
# Number of images in train data 6000
#
# Number of images in train data 1000

# %%
train_img_name[0]
# Out:
# '2513260012_03d33305cf'

# %% [markdown]
# # Load pre-processed captions for Train data (add 'startseq' & 'endseq')

# %%
def load_captions_train(filename):
    doc = load_doc(filename) 
    train_captions = {}    
    
    for line in doc:
        tokens = line.split()
        image_id, image_caption = tokens[0], tokens[1:]

        if(image_id in train_img_name):
            if(image_id not in train_captions):
                train_captions[image_id] = []
            
            modified_caption = 'startseq ' + ' '.join(image_caption) + ' endseq'
            train_captions[image_id].append(modified_caption)
    
    return train_captions


train_captions = load_captions_train('preprocessed_captions.txt')
print(*train_captions['1000268201_693b08cb0e'],sep='\n')
# Out:
# startseq child in pink dress is climbing up set of stairs in an entry way endseq
# startseq girl going into wooden building endseq
# startseq little girl climbing into wooden playhouse endseq
# startseq little girl climbing the stairs to her playhouse endseq
# startseq little girl in pink dress going into wooden cabin endseq

# %%
def preprocess_image(img_path):
    img = image.load_img(img_path,target_size=(299,299)) 
    # type(img): PIL.Image.Image
#     plt.figure(figsize=(12,6))
#     plt.subplot(121)
#     plt.imshow(img)
#     plt.title('Original Image(Resized)')

    img = image.img_to_array(img) # Converts PIL Image instance to numpy array (299,299,3)
    img = np.expand_dims(img, axis=0) #Add one more dimension: (1, 299, 299, 3) # Inception-V3 requires 4 dimensions
    img = preprocess_input(img) # preprocess image as per Inception-V3 model
#     plt.subplot(122)
#     plt.imshow(img[0])
#     plt.title('Preprocessed image for Inception-V3')    
    
    return img  # shape: (1, 299, 299, 3)

# %%
img = preprocess_image('/content/Flicker8k_Dataset/1000268201_693b08cb0e.jpg')
Image.open('/content/Flicker8k_Dataset/preprocessed_image.PNG')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-e9cf4bb47d0f> in <module>()
#       1 img = preprocess_image('/content/Flicker8k_Dataset/1000268201_693b08cb0e.jpg')
# ----> 2 Image.open('/content/Flicker8k_Dataset/preprocessed_image.PNG')
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Flicker8k_Dataset/preprocessed_image.PNG'

# %%
# Load Inception-V3 model
model = InceptionV3(weights='imagenet')

# Create new model, by removing last layer (output layer) from Inception-V3
model_new = Model(inputs=model.input, outputs=model.layers[-2].output) # outputs=(second last layer output)

# model.layers            list of layers
# model.input             <tf.Tensor 'input_1:0' shape=(?, ?, ?, 3) dtype=float32>
# model.layers[-1].output <tf.Tensor 'predictions/Softmax:0' shape=(?, 1000) dtype=float32> 1000 target classes
# model.layers[-2].output <tf.Tensor 'avg_pool/Mean:0' shape=(?, 2048) dtype=float32>

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model_new.predict(img).shape
# Out:
# (1, 2048)

# %% [markdown]
# # All images names

# %%
def images_name(path):
    img_name = set([path+image for image in listdir(path)])
    return img_name

path = '/content/Flicker8k_Dataset'
all_images_name = images_name(path)
train_img_name = [path+'/'+img+'.jpg' for img in train_img_name]
test_img_name = [path+'/'+img+'.jpg' for img in test_img_name]

# %%
train_img_name
# Out:
# ['/content/Flicker8k_Dataset/2513260012_03d33305cf.jpg',
#  '/content/Flicker8k_Dataset/2903617548_d3e38d7f88.jpg',
#  '/content/Flicker8k_Dataset/3338291921_fe7ae0c8f8.jpg',
#  '/content/Flicker8k_Dataset/488416045_1c6d903fe0.jpg',
#  '/content/Flicker8k_Dataset/2644326817_8f45080b87.jpg',
#  '/content/Flicker8k_Dataset/218342358_1755a9cce1.jpg',
#  '/content/Flicker8k_Dataset/2501968935_02f2cd8079.jpg',
#  '/content/Flicker8k_Dataset/2699342860_5288e203ea.jpg',
#  '/content/Flicker8k_Dataset/2638369467_8fc251595b.jpg',
#  '/content/Flicker8k_Dataset/2926786902_815a99a154.jpg',
#  '/content/Flicker8k_Dataset/2851304910_b5721199bc.jpg',
#  '/content/Flicker8k_Dataset/3423802527_94bd2b23b0.jpg',
#  '/content/Flicker8k_Dataset/3356369156_074750c6cc.jpg',
#  '/content/Flicker8k_Dataset/2294598473_40637b5c04.jpg',
#  '/content/Flicker8k_Dataset/1191338263_a4fa073154.jpg',
#  '/content/Flicker8k_Dataset/2380765956_6313d8cae3.jpg',
#  '/content/Flicker8k_Dataset/3197891333_b1b0fd1702.jpg',
#  '/content/Flicker8k_Dataset/3119887967_271a097464.jpg',
#  '/content/Flicker8k_Dataset/2276499757_b44dc6f8ce.jpg',
#  '/content/Flicker8k_Dataset/2506892928_7e79bec613.jpg',
#  '/content/Flicker8k_Dataset/2187222896_c206d63396.jpg',
#  '/content/Flicker8k_Dataset/2826769554_85c90864c9.jpg',
#  '/content/Flicker8k_Dataset/3097196395_ec06075389.jpg',
#  '/content/Flicker8k_Dataset/3603116579_4a28a932e2.jpg',
#  '/content/Flicker8k_Dataset/3339263085_6db9fd0981.jpg',
#  '/content/Flicker8k_Dataset/2532262109_87429a2cae.jpg',
#  '/content/Flicker8k_Dataset/2076906555_c20dc082db.jpg',
#  '/content/Flicker8k_Dataset/2502007071_82a8c639cf.jpg',
#  '/content/Flicker8k_Dataset/3113769557_9edbb8275c.jpg',
#  '/content/Flicker8k_Dataset/3325974730_3ee192e4ff.jpg',
#  '/content/Flicker8k_Dataset/1655781989_b15ab4cbff.jpg',
#  '/content/Flicker8k_Dataset/1662261486_db967930de.jpg',
#  '/content/Flicker8k_Dataset/2410562803_56ec09f41c.jpg',
#  '/content/Flicker8k_Dataset/2469498117_b4543e1460.jpg',
#  '/content/Flicker8k_Dataset/69710415_5c2bfb1058.jpg',
#  '/content/Flicker8k_Dataset/3414734842_beb543f400.jpg',
#  '/content/Flicker8k_Dataset/3006217970_90b42e6b27.jpg',
#  '/content/Flicker8k_Dataset/2192411521_9c7e488c5e.jpg',
#  '/content/Flicker8k_Dataset/3535879138_9281dc83d5.jpg',
#  '/content/Flicker8k_Dataset/2685788323_ceab14534a.jpg',
#  '/content/Flicker8k_Dataset/3465606652_f380a38050.jpg',
#  '/content/Flicker8k_Dataset/2599131872_65789d86d5.jpg',
#  '/content/Flicker8k_Dataset/2244613488_4d1f9edb33.jpg',
#  '/content/Flicker8k_Dataset/2738077433_10e6264b6f.jpg',
#  '/content/Flicker8k_Dataset/3537201804_ce07aff237.jpg',
#  '/content/Flicker8k_Dataset/1597557856_30640e0b43.jpg',
#  '/content/Flicker8k_Dataset/3357194782_c261bb6cbf.jpg',
#  '/content/Flicker8k_Dataset/3682038869_585075b5ff.jpg',
#  '/content/Flicker8k_Dataset/236474697_0c73dd5d8b.jpg',
#  '/content/Flicker8k_Dataset/2641288004_30ce961211.jpg',
#  '/content/Flicker8k_Dataset/267164457_2e8b4d30aa.jpg',
#  '/content/Flicker8k_Dataset/2453891449_fedb277908.jpg',
#  '/content/Flicker8k_Dataset/281419391_522557ce27.jpg',
#  '/content/Flicker8k_Dataset/354999632_915ea81e53.jpg',
#  '/content/Flicker8k_Dataset/3109136206_f7d201b368.jpg',
#  '/content/Flicker8k_Dataset/2281054343_95d6d3b882.jpg',
#  '/content/Flicker8k_Dataset/3296584432_bef3c965a3.jpg',
#  '/content/Flicker8k_Dataset/3526431764_056d2c61dc.jpg',
#  '/content/Flicker8k_Dataset/3549997413_01388dece0.jpg',
#  '/content/Flicker8k_Dataset/143688895_e837c3bc76.jpg',
#  '/content/Flicker8k_Dataset/2495394666_2ef6c37519.jpg',
#  '/content/Flicker8k_Dataset/3384742888_85230c34d5.jpg',
#  '/content/Flicker8k_Dataset/1160034462_16b38174fe.jpg',
#  '/content/Flicker8k_Dataset/334768700_51c439b9ee.jpg',
#  '/content/Flicker8k_Dataset/412101267_7257e6d8c0.jpg',
#  '/content/Flicker8k_Dataset/2623939135_0cd02ffa5d.jpg',
#  '/content/Flicker8k_Dataset/3043266735_904dda6ded.jpg',
#  '/content/Flicker8k_Dataset/3034585889_388d6ffcc0.jpg',
#  '/content/Flicker8k_Dataset/2069279767_fb32bfb2de.jpg',
#  '/content/Flicker8k_Dataset/2593406865_ab98490c1f.jpg',
#  '/content/Flicker8k_Dataset/432167214_c17fcc1a2d.jpg',
#  '/content/Flicker8k_Dataset/305749904_54a612fd1a.jpg',
#  '/content/Flicker8k_Dataset/2780087302_6a77658cbf.jpg',
#  '/content/Flicker8k_Dataset/3051998298_38da5746fa.jpg',
#  '/content/Flicker8k_Dataset/1574401950_6bedc0d29b.jpg',
#  '/content/Flicker8k_Dataset/539493431_744eb1abaa.jpg',
#  '/content/Flicker8k_Dataset/3524436870_7670df68e8.jpg',
#  '/content/Flicker8k_Dataset/2081446176_f97dc76951.jpg',
#  '/content/Flicker8k_Dataset/2265367960_7928c5642f.jpg',
#  '/content/Flicker8k_Dataset/460350019_af60511a3b.jpg',
#  '/content/Flicker8k_Dataset/2976946039_fb9147908d.jpg',
#  '/content/Flicker8k_Dataset/2308108566_2cba6bca53.jpg',
#  '/content/Flicker8k_Dataset/3367758711_a8c09607ac.jpg',
#  '/content/Flicker8k_Dataset/3666056567_661e25f54c.jpg',
#  '/content/Flicker8k_Dataset/3099264059_21653e2536.jpg',
#  '/content/Flicker8k_Dataset/2988439935_7cea05bc48.jpg',
#  '/content/Flicker8k_Dataset/241345864_138471c9ea.jpg',
#  '/content/Flicker8k_Dataset/3019199755_a984bc21b1.jpg',
#  '/content/Flicker8k_Dataset/3201594926_cd2009eb13.jpg',
#  '/content/Flicker8k_Dataset/2540751930_d71c7f5622.jpg',
#  '/content/Flicker8k_Dataset/1475046848_831245fc64.jpg',
#  '/content/Flicker8k_Dataset/2877637572_641cd29901.jpg',
#  '/content/Flicker8k_Dataset/1308472581_9961782889.jpg',
#  '/content/Flicker8k_Dataset/2282260240_55387258de.jpg',
#  '/content/Flicker8k_Dataset/2363419943_717e6b119d.jpg',
#  '/content/Flicker8k_Dataset/392976422_c8d0514bc3.jpg',
#  '/content/Flicker8k_Dataset/103205630_682ca7285b.jpg',
#  '/content/Flicker8k_Dataset/1347519824_e402241e4f.jpg',
#  '/content/Flicker8k_Dataset/584484388_0eeb36d03d.jpg',
#  '/content/Flicker8k_Dataset/2460823604_7f6f786b1c.jpg',
#  '/content/Flicker8k_Dataset/121800200_bef08fae5f.jpg',
#  '/content/Flicker8k_Dataset/2422302286_385725e3cf.jpg',
#  '/content/Flicker8k_Dataset/3183883750_b6acc40397.jpg',
#  '/content/Flicker8k_Dataset/3091912922_0d6ebc8f6a.jpg',
#  '/content/Flicker8k_Dataset/2787868417_810985234d.jpg',
#  '/content/Flicker8k_Dataset/3670075789_92ea9a183a.jpg',
#  '/content/Flicker8k_Dataset/3329169877_175cb16845.jpg',
#  '/content/Flicker8k_Dataset/751074141_feafc7b16c.jpg',
#  '/content/Flicker8k_Dataset/3445428367_25bafffe75.jpg',
#  '/content/Flicker8k_Dataset/3542418447_7c337360d6.jpg',
#  '/content/Flicker8k_Dataset/2730819220_b58af1119a.jpg',
#  '/content/Flicker8k_Dataset/3543378438_47e2712486.jpg',
#  '/content/Flicker8k_Dataset/2335619125_2e2034f2c3.jpg',
#  '/content/Flicker8k_Dataset/3520199925_ca18d0f41e.jpg',
#  '/content/Flicker8k_Dataset/3374722123_6fe6fef449.jpg',
#  '/content/Flicker8k_Dataset/3280672302_2967177653.jpg',
#  '/content/Flicker8k_Dataset/3073579130_7c95d16a7f.jpg',
#  '/content/Flicker8k_Dataset/99679241_adc853a5c0.jpg',
#  '/content/Flicker8k_Dataset/3759492488_592cd78ed1.jpg',
#  '/content/Flicker8k_Dataset/2875528143_94d9480fdd.jpg',
#  '/content/Flicker8k_Dataset/1052358063_eae6744153.jpg',
#  '/content/Flicker8k_Dataset/111766423_4522d36e56.jpg',
#  '/content/Flicker8k_Dataset/2474918824_88660c7757.jpg',
#  '/content/Flicker8k_Dataset/3697675767_97796334e4.jpg',
#  '/content/Flicker8k_Dataset/241346317_be3f07bd2e.jpg',
#  '/content/Flicker8k_Dataset/2694178830_116be6a6a9.jpg',
#  '/content/Flicker8k_Dataset/513116697_ad0f4dc800.jpg',
#  '/content/Flicker8k_Dataset/371364900_5167d4dd7f.jpg',
#  '/content/Flicker8k_Dataset/2860041212_797afd6ccf.jpg',
#  '/content/Flicker8k_Dataset/1481062342_d9e34366c4.jpg',
#  '/content/Flicker8k_Dataset/3556792157_d09d42bef7.jpg',
#  '/content/Flicker8k_Dataset/3226254560_2f8ac147ea.jpg',
#  '/content/Flicker8k_Dataset/2252123185_487f21e336.jpg',
#  '/content/Flicker8k_Dataset/2353088412_5e5804c6f5.jpg',
#  '/content/Flicker8k_Dataset/3359587274_4a2b140b84.jpg',
#  '/content/Flicker8k_Dataset/3588417747_b152a51c52.jpg',
#  '/content/Flicker8k_Dataset/1055623002_8195a43714.jpg',
#  '/content/Flicker8k_Dataset/3454315016_f1e30d4676.jpg',
#  '/content/Flicker8k_Dataset/2837808847_5407af1986.jpg',
#  '/content/Flicker8k_Dataset/3544803461_a418ca611e.jpg',
#  '/content/Flicker8k_Dataset/3046916429_8e2570b613.jpg',
#  '/content/Flicker8k_Dataset/2570559405_dc93007f76.jpg',
#  '/content/Flicker8k_Dataset/2518219912_f47214aa16.jpg',
#  '/content/Flicker8k_Dataset/2951092164_4940b9a517.jpg',
#  '/content/Flicker8k_Dataset/2273038287_3004a72a34.jpg',
#  '/content/Flicker8k_Dataset/3710971182_cb01c97d15.jpg',
#  '/content/Flicker8k_Dataset/3544483327_830349e7bc.jpg',
#  '/content/Flicker8k_Dataset/3055716848_b253324afc.jpg',
#  '/content/Flicker8k_Dataset/3287236038_8998e6b82f.jpg',
#  '/content/Flicker8k_Dataset/3597210806_95b07bb968.jpg',
#  '/content/Flicker8k_Dataset/3453284877_8866189055.jpg',
#  '/content/Flicker8k_Dataset/2640000969_b5404a5143.jpg',
#  '/content/Flicker8k_Dataset/2451988767_244bff98d1.jpg',
#  '/content/Flicker8k_Dataset/3682428916_69ce66d375.jpg',
#  '/content/Flicker8k_Dataset/276356412_dfa01c3c9e.jpg',
#  '/content/Flicker8k_Dataset/3616846215_d61881b60f.jpg',
#  '/content/Flicker8k_Dataset/2360194369_d2fd03b337.jpg',
#  '/content/Flicker8k_Dataset/576093768_e78f91c176.jpg',
#  '/content/Flicker8k_Dataset/2934837034_a8ca5b1f50.jpg',
#  '/content/Flicker8k_Dataset/241345639_1556a883b1.jpg',
#  '/content/Flicker8k_Dataset/2876994989_a4ebbd8491.jpg',
#  '/content/Flicker8k_Dataset/2339516180_12493e8ecf.jpg',
#  '/content/Flicker8k_Dataset/3301438465_10121a2412.jpg',
#  '/content/Flicker8k_Dataset/101669240_b2d3e7f17b.jpg',
#  '/content/Flicker8k_Dataset/300500054_56653bf217.jpg',
#  '/content/Flicker8k_Dataset/1956678973_223cb1b847.jpg',
#  '/content/Flicker8k_Dataset/1213336750_2269b51397.jpg',
#  '/content/Flicker8k_Dataset/478750151_e0adb5030a.jpg',
#  '/content/Flicker8k_Dataset/2755952680_68a0a1fa42.jpg',
#  '/content/Flicker8k_Dataset/47870024_73a4481f7d.jpg',
#  '/content/Flicker8k_Dataset/3165826902_6bf9c4bdb2.jpg',
#  '/content/Flicker8k_Dataset/2839890871_4b7c7dbd96.jpg',
#  '/content/Flicker8k_Dataset/3710468717_c051d96a5f.jpg',
#  '/content/Flicker8k_Dataset/3272541970_ac0f1de274.jpg',
#  '/content/Flicker8k_Dataset/543363241_74d8246fab.jpg',
#  '/content/Flicker8k_Dataset/2661437618_ca7a15f3cb.jpg',
#  '/content/Flicker8k_Dataset/2696636252_91ef1491ea.jpg',
#  '/content/Flicker8k_Dataset/3092756650_557c5f2d03.jpg',
#  '/content/Flicker8k_Dataset/3241965735_8742782a70.jpg',
#  '/content/Flicker8k_Dataset/3174417550_d2e6100278.jpg',
#  '/content/Flicker8k_Dataset/2712352554_1cafd32812.jpg',
#  '/content/Flicker8k_Dataset/3371567346_b6522efdb8.jpg',
#  '/content/Flicker8k_Dataset/2102315758_a9148a842f.jpg',
#  '/content/Flicker8k_Dataset/3249891130_b241591e89.jpg',
#  '/content/Flicker8k_Dataset/488196964_49159f11fd.jpg',
#  '/content/Flicker8k_Dataset/2056041678_d6b5b39b26.jpg',
#  '/content/Flicker8k_Dataset/2613993276_3c365cca12.jpg',
#  '/content/Flicker8k_Dataset/2571096893_694ce79768.jpg',
#  '/content/Flicker8k_Dataset/2245618207_fa486ba2b7.jpg',
#  '/content/Flicker8k_Dataset/3025513877_1a6160070d.jpg',
#  '/content/Flicker8k_Dataset/3638783842_af08dbb518.jpg',
#  '/content/Flicker8k_Dataset/2629295654_59ea1472a1.jpg',
#  '/content/Flicker8k_Dataset/3691670743_0ed111bcf3.jpg',
#  '/content/Flicker8k_Dataset/1368338041_6b4077ca98.jpg',
#  '/content/Flicker8k_Dataset/2876848241_63290edfb4.jpg',
#  '/content/Flicker8k_Dataset/3150380412_7021e5444a.jpg',
#  '/content/Flicker8k_Dataset/380034515_4fbdfa6b26.jpg',
#  '/content/Flicker8k_Dataset/2646615552_3aeeb2473b.jpg',
#  '/content/Flicker8k_Dataset/2862509442_4f5dc96dca.jpg',
#  '/content/Flicker8k_Dataset/2333584535_1eaf9baf3e.jpg',
#  '/content/Flicker8k_Dataset/3382105769_b1a4e4c60d.jpg',
#  '/content/Flicker8k_Dataset/284441196_8ebb216d0d.jpg',
#  '/content/Flicker8k_Dataset/2371809188_b805497cba.jpg',
#  '/content/Flicker8k_Dataset/3120648767_812c72eabe.jpg',
#  '/content/Flicker8k_Dataset/449287870_f17fb825d7.jpg',
#  '/content/Flicker8k_Dataset/3242919570_39a05aa2ee.jpg',
#  '/content/Flicker8k_Dataset/950411653_20d0335946.jpg',
#  '/content/Flicker8k_Dataset/3209350613_eb86579ee8.jpg',
#  '/content/Flicker8k_Dataset/811662356_f9a632b63c.jpg',
#  '/content/Flicker8k_Dataset/3027009366_c8362521e8.jpg',
#  '/content/Flicker8k_Dataset/2982928615_06db40f4cd.jpg',
#  '/content/Flicker8k_Dataset/3040575300_0e4328d205.jpg',
#  '/content/Flicker8k_Dataset/2883324329_24361e2d49.jpg',
#  '/content/Flicker8k_Dataset/3503544012_1771be9d3a.jpg',
#  '/content/Flicker8k_Dataset/524031846_28b11bc0e5.jpg',
#  '/content/Flicker8k_Dataset/3343311201_eeb1a39def.jpg',
#  '/content/Flicker8k_Dataset/3721082512_8277087f3f.jpg',
#  '/content/Flicker8k_Dataset/3286193613_fc046e8016.jpg',
#  '/content/Flicker8k_Dataset/3667492609_97f88b373f.jpg',
#  '/content/Flicker8k_Dataset/3370085095_6abbb67c1d.jpg',
#  '/content/Flicker8k_Dataset/3351360323_91bb341350.jpg',
#  '/content/Flicker8k_Dataset/2173677067_9d0732bcc2.jpg',
#  '/content/Flicker8k_Dataset/3534952095_975cca0056.jpg',
#  '/content/Flicker8k_Dataset/2750867389_4b815f793a.jpg',
#  '/content/Flicker8k_Dataset/2256138896_3e24b0b28d.jpg',
#  '/content/Flicker8k_Dataset/310728631_155c3bbeea.jpg',
#  '/content/Flicker8k_Dataset/3204712107_5a06a81002.jpg',
#  '/content/Flicker8k_Dataset/281754914_bc8119a0ed.jpg',
#  '/content/Flicker8k_Dataset/3612249030_e2829ffa31.jpg',
#  '/content/Flicker8k_Dataset/349889354_4b2889a9bd.jpg',
#  '/content/Flicker8k_Dataset/2596876977_b61ee7ee78.jpg',
#  '/content/Flicker8k_Dataset/3524975665_7bec41578b.jpg',
#  '/content/Flicker8k_Dataset/2786299623_a3c48bd318.jpg',
#  '/content/Flicker8k_Dataset/3298233193_d2a550840d.jpg',
#  '/content/Flicker8k_Dataset/3356938707_d95ba97430.jpg',
#  '/content/Flicker8k_Dataset/3104182973_5bb1c31275.jpg',
#  '/content/Flicker8k_Dataset/299612419_b55fe32fea.jpg',
#  '/content/Flicker8k_Dataset/488352274_9a22064cb3.jpg',
#  '/content/Flicker8k_Dataset/2673564214_3a9598804f.jpg',
#  '/content/Flicker8k_Dataset/3127142756_bf0bfcb571.jpg',
#  '/content/Flicker8k_Dataset/3348785391_c243faf6bb.jpg',
#  '/content/Flicker8k_Dataset/3155501473_510f9c9f6b.jpg',
#  '/content/Flicker8k_Dataset/1446933195_8fe9725d62.jpg',
#  '/content/Flicker8k_Dataset/2912476706_9a0dbd3a67.jpg',
#  '/content/Flicker8k_Dataset/3447007090_08d997833a.jpg',
#  '/content/Flicker8k_Dataset/2435166927_28b8130660.jpg',
#  '/content/Flicker8k_Dataset/2809793070_1a3387cd6e.jpg',
#  '/content/Flicker8k_Dataset/2284239186_c827f4defa.jpg',
#  '/content/Flicker8k_Dataset/3293751136_b0ce285dc3.jpg',
#  '/content/Flicker8k_Dataset/2591455200_2319651f2f.jpg',
#  '/content/Flicker8k_Dataset/2862481071_86c65d46fa.jpg',
#  '/content/Flicker8k_Dataset/3162442331_c9711857c6.jpg',
#  '/content/Flicker8k_Dataset/3117336911_a729f42869.jpg',
#  '/content/Flicker8k_Dataset/805682444_90ed9e1ef3.jpg',
#  '/content/Flicker8k_Dataset/299181827_8dc714101b.jpg',
#  '/content/Flicker8k_Dataset/2990471798_73c50c76fb.jpg',
#  '/content/Flicker8k_Dataset/2127031632_77505e4218.jpg',
#  '/content/Flicker8k_Dataset/3096163135_584901a5ae.jpg',
#  '/content/Flicker8k_Dataset/2921112724_5cb85d7413.jpg',
#  '/content/Flicker8k_Dataset/2815745115_c8479d560c.jpg',
#  '/content/Flicker8k_Dataset/3041689520_c481bdb20e.jpg',
#  '/content/Flicker8k_Dataset/413737417_b0a8b445e9.jpg',
#  '/content/Flicker8k_Dataset/3635177305_bfbe1fc348.jpg',
#  '/content/Flicker8k_Dataset/3286111436_891ae7dab9.jpg',
#  '/content/Flicker8k_Dataset/460973814_5eacd1ced4.jpg',
#  '/content/Flicker8k_Dataset/3384528359_e920154177.jpg',
#  '/content/Flicker8k_Dataset/3429194423_98e911a101.jpg',
#  '/content/Flicker8k_Dataset/2971211296_2587c3924d.jpg',
#  '/content/Flicker8k_Dataset/3474912569_7165dc1d06.jpg',
#  '/content/Flicker8k_Dataset/2888408966_376c195b3f.jpg',
#  '/content/Flicker8k_Dataset/1965278563_8279e408de.jpg',
#  '/content/Flicker8k_Dataset/3431194126_ca78f5fde6.jpg',
#  '/content/Flicker8k_Dataset/2407470303_6fd5e3600d.jpg',
#  '/content/Flicker8k_Dataset/3625049113_554d82c2a1.jpg',
#  '/content/Flicker8k_Dataset/468918320_9c275b877f.jpg',
#  '/content/Flicker8k_Dataset/2507182524_7e83c6de82.jpg',
#  '/content/Flicker8k_Dataset/241347214_5f19e7998c.jpg',
#  '/content/Flicker8k_Dataset/1386251841_5f384a0fea.jpg',
#  '/content/Flicker8k_Dataset/3715559023_70c41b31c7.jpg',
#  '/content/Flicker8k_Dataset/3643087589_627a0a9e01.jpg',
#  '/content/Flicker8k_Dataset/2705947033_5999147842.jpg',
#  '/content/Flicker8k_Dataset/241347635_e691395c2f.jpg',
#  '/content/Flicker8k_Dataset/2560278143_aa5110aa37.jpg',
#  '/content/Flicker8k_Dataset/3107368071_724613fc4f.jpg',
#  '/content/Flicker8k_Dataset/3368207495_1e2dbd6d3f.jpg',
#  '/content/Flicker8k_Dataset/3725814794_30db172f67.jpg',
#  '/content/Flicker8k_Dataset/746787916_ceb103069f.jpg',
#  '/content/Flicker8k_Dataset/2584487952_f70e5aa9bf.jpg',
#  '/content/Flicker8k_Dataset/3211453055_05cbfe37cd.jpg',
#  '/content/Flicker8k_Dataset/1012212859_01547e3f17.jpg',
#  '/content/Flicker8k_Dataset/3406116788_c8f62e32d1.jpg',
#  '/content/Flicker8k_Dataset/3583704941_611353857e.jpg',
#  '/content/Flicker8k_Dataset/3259229498_2b5708c0c6.jpg',
#  '/content/Flicker8k_Dataset/506808265_fe84ada926.jpg',
#  '/content/Flicker8k_Dataset/652542470_60e858da64.jpg',
#  '/content/Flicker8k_Dataset/2551632823_0cb7dd779b.jpg',
#  '/content/Flicker8k_Dataset/2780105274_52360c4cca.jpg',
#  '/content/Flicker8k_Dataset/459284240_5a4167bf92.jpg',
#  '/content/Flicker8k_Dataset/155221027_b23a4331b7.jpg',
#  '/content/Flicker8k_Dataset/270263570_3160f360d3.jpg',
#  '/content/Flicker8k_Dataset/2757779501_c41c86a595.jpg',
#  '/content/Flicker8k_Dataset/129599450_cab4e77343.jpg',
#  '/content/Flicker8k_Dataset/3004290523_d1319dfdb4.jpg',
#  '/content/Flicker8k_Dataset/3582465732_78f77f34ae.jpg',
#  '/content/Flicker8k_Dataset/1110208841_5bb6806afe.jpg',
#  '/content/Flicker8k_Dataset/278559394_b23af734b9.jpg',
#  '/content/Flicker8k_Dataset/2883950737_3b67d24af4.jpg',
#  '/content/Flicker8k_Dataset/3496983524_b21ecdb0c7.jpg',
#  '/content/Flicker8k_Dataset/466956675_a2fb6bf901.jpg',
#  '/content/Flicker8k_Dataset/3501781809_88429e3b83.jpg',
#  '/content/Flicker8k_Dataset/1425013325_bff69bc9da.jpg',
#  '/content/Flicker8k_Dataset/2181117039_c4eea8036e.jpg',
#  '/content/Flicker8k_Dataset/571507143_be346225b7.jpg',
#  '/content/Flicker8k_Dataset/3528251308_481a28283a.jpg',
#  '/content/Flicker8k_Dataset/2261962622_e9318a95eb.jpg',
#  '/content/Flicker8k_Dataset/517094985_4b9e926936.jpg',
#  '/content/Flicker8k_Dataset/297285273_688e44c014.jpg',
#  '/content/Flicker8k_Dataset/3487419819_e3f89444ce.jpg',
#  '/content/Flicker8k_Dataset/837919879_94e3dacd83.jpg',
#  '/content/Flicker8k_Dataset/3276475986_66cd9cc7e4.jpg',
#  '/content/Flicker8k_Dataset/3027399066_ca85495775.jpg',
#  '/content/Flicker8k_Dataset/1412832223_99e8b4701a.jpg',
#  '/content/Flicker8k_Dataset/2596100297_372bd0f739.jpg',
#  '/content/Flicker8k_Dataset/2149982207_5345633bbf.jpg',
#  '/content/Flicker8k_Dataset/470887795_8443ce53d0.jpg',
#  '/content/Flicker8k_Dataset/1463732807_0cdf4f22c7.jpg',
#  '/content/Flicker8k_Dataset/2464259416_238ef13a2e.jpg',
#  '/content/Flicker8k_Dataset/2869253972_aa72df6bf3.jpg',
#  '/content/Flicker8k_Dataset/1124448967_2221af8dc5.jpg',
#  '/content/Flicker8k_Dataset/3025546819_ce031d2fc3.jpg',
#  '/content/Flicker8k_Dataset/55473406_1d2271c1f2.jpg',
#  '/content/Flicker8k_Dataset/2219959872_988e6d498e.jpg',
#  '/content/Flicker8k_Dataset/747242766_afdc9cb2ba.jpg',
#  '/content/Flicker8k_Dataset/3344948183_5b89379585.jpg',
#  '/content/Flicker8k_Dataset/526661994_21838fc72c.jpg',
#  '/content/Flicker8k_Dataset/2505360288_c972bd29c4.jpg',
#  '/content/Flicker8k_Dataset/2934000107_d2ff15c814.jpg',
#  '/content/Flicker8k_Dataset/3124549928_10904a5a83.jpg',
#  '/content/Flicker8k_Dataset/2930514856_784f17064a.jpg',
#  '/content/Flicker8k_Dataset/2477623312_58e8e8c8af.jpg',
#  '/content/Flicker8k_Dataset/3634032601_2236676cdd.jpg',
#  '/content/Flicker8k_Dataset/2973272684_4d63cbc241.jpg',
#  '/content/Flicker8k_Dataset/2108799322_e25aa6e185.jpg',
#  '/content/Flicker8k_Dataset/3628017876_4ac27e687b.jpg',
#  '/content/Flicker8k_Dataset/3465396606_5ba1574128.jpg',
#  '/content/Flicker8k_Dataset/2789688929_9424fceed1.jpg',
#  '/content/Flicker8k_Dataset/3522076584_7c603d2ac5.jpg',
#  '/content/Flicker8k_Dataset/3662909101_21b9e59a3e.jpg',
#  '/content/Flicker8k_Dataset/1453366750_6e8cf601bf.jpg',
#  '/content/Flicker8k_Dataset/2267682214_e1434d853b.jpg',
#  '/content/Flicker8k_Dataset/2058472558_7dd5014abd.jpg',
#  '/content/Flicker8k_Dataset/3638908276_b1751d30ff.jpg',
#  '/content/Flicker8k_Dataset/3016726158_4d15b83b06.jpg',
#  '/content/Flicker8k_Dataset/2191453879_11dfe2ba3a.jpg',
#  '/content/Flicker8k_Dataset/3441531010_8eebbb507e.jpg',
#  '/content/Flicker8k_Dataset/1529044279_4922ead27c.jpg',
#  '/content/Flicker8k_Dataset/429174232_ddd4ff5e0b.jpg',
#  '/content/Flicker8k_Dataset/3451085951_e66f7f5d5c.jpg',
#  '/content/Flicker8k_Dataset/3568505408_4e30def669.jpg',
#  '/content/Flicker8k_Dataset/2271671533_7538ccd556.jpg',
#  '/content/Flicker8k_Dataset/3153067758_53f003b1df.jpg',
#  '/content/Flicker8k_Dataset/2510029990_7014f907cb.jpg',
#  '/content/Flicker8k_Dataset/562588230_edb2c071c8.jpg',
#  '/content/Flicker8k_Dataset/1801188148_a176954965.jpg',
#  '/content/Flicker8k_Dataset/3260975858_75d0612a69.jpg',
#  '/content/Flicker8k_Dataset/397547349_1fd14b95af.jpg',
#  '/content/Flicker8k_Dataset/3091338773_9cf10467b4.jpg',
#  '/content/Flicker8k_Dataset/3479423813_517e93a43a.jpg',
#  '/content/Flicker8k_Dataset/3703413486_3c682732a0.jpg',
#  '/content/Flicker8k_Dataset/2978271431_f6a7f19825.jpg',
#  '/content/Flicker8k_Dataset/3421104520_6a71185b3c.jpg',
#  '/content/Flicker8k_Dataset/440184957_267f3f3a2b.jpg',
#  '/content/Flicker8k_Dataset/1390268323_2c8204e91c.jpg',
#  '/content/Flicker8k_Dataset/3436418401_b00ceb27c0.jpg',
#  '/content/Flicker8k_Dataset/3448855727_f16dea7b03.jpg',
#  '/content/Flicker8k_Dataset/404216567_75b50b5a36.jpg',
#  '/content/Flicker8k_Dataset/2882893687_1d10d68f2b.jpg',
#  '/content/Flicker8k_Dataset/3047144646_2252ff8e04.jpg',
#  '/content/Flicker8k_Dataset/2058124718_89822bc96e.jpg',
#  '/content/Flicker8k_Dataset/3319020762_d429d56a69.jpg',
#  '/content/Flicker8k_Dataset/1387461595_2fe6925f73.jpg',
#  '/content/Flicker8k_Dataset/597543181_6a85ef4c17.jpg',
#  '/content/Flicker8k_Dataset/3000722396_1ae2e976c2.jpg',
#  '/content/Flicker8k_Dataset/3638178504_be1ff246bd.jpg',
#  '/content/Flicker8k_Dataset/2394919002_ed7527ff93.jpg',
#  '/content/Flicker8k_Dataset/1384292980_4022a7520c.jpg',
#  '/content/Flicker8k_Dataset/2925737498_57585a7ed9.jpg',
#  '/content/Flicker8k_Dataset/2784625888_71a421e171.jpg',
#  '/content/Flicker8k_Dataset/3159424456_f316bdc1d5.jpg',
#  '/content/Flicker8k_Dataset/2707835735_6537b27e8f.jpg',
#  '/content/Flicker8k_Dataset/236518934_c62a133077.jpg',
#  '/content/Flicker8k_Dataset/1463638541_c02cfa04dc.jpg',
#  '/content/Flicker8k_Dataset/2635938723_11b85e6763.jpg',
#  '/content/Flicker8k_Dataset/421808539_57abee6d55.jpg',
#  '/content/Flicker8k_Dataset/3644142276_caed26029e.jpg',
#  '/content/Flicker8k_Dataset/3126795109_73920ed5dc.jpg',
#  '/content/Flicker8k_Dataset/3547368652_0d85c665d3.jpg',
#  '/content/Flicker8k_Dataset/3136404885_f4d8f1d15a.jpg',
#  '/content/Flicker8k_Dataset/2510197716_fddca0ac75.jpg',
#  '/content/Flicker8k_Dataset/1019604187_d087bf9a5f.jpg',
#  '/content/Flicker8k_Dataset/2991771557_d98fa0a69f.jpg',
#  '/content/Flicker8k_Dataset/314940358_ec1958dc1d.jpg',
#  '/content/Flicker8k_Dataset/451326127_2d95a2e1c2.jpg',
#  '/content/Flicker8k_Dataset/3547499166_67fb4af4ea.jpg',
#  '/content/Flicker8k_Dataset/3326249355_e7a7c71f06.jpg',
#  '/content/Flicker8k_Dataset/2252403744_148fc11f68.jpg',
#  '/content/Flicker8k_Dataset/3016200560_5bf8a70797.jpg',
#  '/content/Flicker8k_Dataset/2086532897_b8714f2237.jpg',
#  '/content/Flicker8k_Dataset/453756106_711c20471a.jpg',
#  '/content/Flicker8k_Dataset/3134586018_ae03ba20a0.jpg',
#  '/content/Flicker8k_Dataset/2042009399_afad34e7c1.jpg',
#  '/content/Flicker8k_Dataset/3104400277_1524e4f758.jpg',
#  '/content/Flicker8k_Dataset/1501811302_5e723fc529.jpg',
#  '/content/Flicker8k_Dataset/3174713468_e22fa7779e.jpg',
#  '/content/Flicker8k_Dataset/3345025842_bc2082a509.jpg',
#  '/content/Flicker8k_Dataset/2261257940_449b6e6c91.jpg',
#  '/content/Flicker8k_Dataset/485357535_b45ba5b6da.jpg',
#  '/content/Flicker8k_Dataset/3639617775_149001232a.jpg',
#  '/content/Flicker8k_Dataset/3404870997_7b0cd755de.jpg',
#  '/content/Flicker8k_Dataset/2565350330_c7f305e7f7.jpg',
#  '/content/Flicker8k_Dataset/2587017287_888c811b5a.jpg',
#  '/content/Flicker8k_Dataset/3262760716_1e9734f5ba.jpg',
#  '/content/Flicker8k_Dataset/487071033_27e460a1b9.jpg',
#  '/content/Flicker8k_Dataset/3566111626_9a35a7b2c0.jpg',
#  '/content/Flicker8k_Dataset/2310108346_e82d209ccd.jpg',
#  '/content/Flicker8k_Dataset/3172369593_eb4d787ffb.jpg',
#  '/content/Flicker8k_Dataset/2384401298_e389c01abc.jpg',
#  '/content/Flicker8k_Dataset/3451523035_b61d79f6a8.jpg',
#  '/content/Flicker8k_Dataset/3090600019_8808fe7a9d.jpg',
#  '/content/Flicker8k_Dataset/2437266971_b91a8f9a00.jpg',
#  '/content/Flicker8k_Dataset/3633396324_c4b24b1f51.jpg',
#  '/content/Flicker8k_Dataset/2561319255_ce5ede291e.jpg',
#  '/content/Flicker8k_Dataset/2892395757_0a1b0eedd2.jpg',
#  '/content/Flicker8k_Dataset/1417637704_572b4d6557.jpg',
#  '/content/Flicker8k_Dataset/3465000218_c94e54e208.jpg',
#  '/content/Flicker8k_Dataset/2613021139_4b0dc3d4c8.jpg',
#  '/content/Flicker8k_Dataset/2086678529_b3301c2d71.jpg',
#  '/content/Flicker8k_Dataset/781118358_19087c9ec0.jpg',
#  '/content/Flicker8k_Dataset/2999162229_80d17099b6.jpg',
#  '/content/Flicker8k_Dataset/3163273640_8d3ef22eaf.jpg',
#  '/content/Flicker8k_Dataset/3014080715_f4f0dbb56e.jpg',
#  '/content/Flicker8k_Dataset/543264612_c53cc163b4.jpg',
#  '/content/Flicker8k_Dataset/1313961775_824b87d155.jpg',
#  '/content/Flicker8k_Dataset/2328104318_5a43ca170c.jpg',
#  '/content/Flicker8k_Dataset/3519942322_b37d088aae.jpg',
#  '/content/Flicker8k_Dataset/166321294_4a5e68535f.jpg',
#  '/content/Flicker8k_Dataset/3427852996_d383abd819.jpg',
#  '/content/Flicker8k_Dataset/2540360421_f7c2401da8.jpg',
#  '/content/Flicker8k_Dataset/207275121_ee4dfa0bf2.jpg',
#  '/content/Flicker8k_Dataset/211277478_7d43aaee09.jpg',
#  '/content/Flicker8k_Dataset/492341908_1ef53be265.jpg',
#  '/content/Flicker8k_Dataset/2817230861_d27341dec0.jpg',
#  '/content/Flicker8k_Dataset/3155365418_43df5486f9.jpg',
#  '/content/Flicker8k_Dataset/848180689_d67a1361ce.jpg',
#  '/content/Flicker8k_Dataset/3436395540_63bc8f2fe0.jpg',
#  '/content/Flicker8k_Dataset/2220175999_081aa9cce8.jpg',
#  '/content/Flicker8k_Dataset/292780636_72e1968949.jpg',
#  '/content/Flicker8k_Dataset/3150440350_b0f2a9e774.jpg',
#  '/content/Flicker8k_Dataset/1234293791_6566284bcd.jpg',
#  '/content/Flicker8k_Dataset/381976882_0063d16d88.jpg',
#  '/content/Flicker8k_Dataset/141139674_246c0f90a1.jpg',
#  '/content/Flicker8k_Dataset/3116039960_54d1d68145.jpg',
#  '/content/Flicker8k_Dataset/3106857210_07a92577fc.jpg',
#  '/content/Flicker8k_Dataset/1121416483_c7902d0d49.jpg',
#  '/content/Flicker8k_Dataset/2439154641_bbf985aa57.jpg',
#  '/content/Flicker8k_Dataset/2706430695_3b5667741c.jpg',
#  '/content/Flicker8k_Dataset/3478084305_9e1219c3b6.jpg',
#  '/content/Flicker8k_Dataset/3008370541_ce29ce49f0.jpg',
#  '/content/Flicker8k_Dataset/2947274789_a1a35b33c3.jpg',
#  '/content/Flicker8k_Dataset/3336065481_2c21e622c8.jpg',
#  '/content/Flicker8k_Dataset/1057210460_09c6f4c6c1.jpg',
#  '/content/Flicker8k_Dataset/2560388887_55abc9083d.jpg',
#  '/content/Flicker8k_Dataset/836768303_d748df5546.jpg',
#  '/content/Flicker8k_Dataset/3352531708_a65dd694b1.jpg',
#  '/content/Flicker8k_Dataset/1402843760_d30f1dbf0f.jpg',
#  '/content/Flicker8k_Dataset/3342309960_c694b2cce9.jpg',
#  '/content/Flicker8k_Dataset/948196883_e190a483b1.jpg',
#  '/content/Flicker8k_Dataset/3392293702_ccb0599857.jpg',
#  '/content/Flicker8k_Dataset/458183774_afe65abf67.jpg',
#  '/content/Flicker8k_Dataset/3172283002_3c0fc624de.jpg',
#  '/content/Flicker8k_Dataset/186890601_8a6b0f1769.jpg',
#  '/content/Flicker8k_Dataset/3417102649_5c0b2f4b4d.jpg',
#  '/content/Flicker8k_Dataset/3337461409_e4e317853d.jpg',
#  '/content/Flicker8k_Dataset/3611603026_9112b0c53f.jpg',
#  '/content/Flicker8k_Dataset/3084731832_8e518e320d.jpg',
#  '/content/Flicker8k_Dataset/289599470_cc665e2dfb.jpg',
#  '/content/Flicker8k_Dataset/3533484468_0787830d49.jpg',
#  '/content/Flicker8k_Dataset/3225478803_f7a9a41a1d.jpg',
#  '/content/Flicker8k_Dataset/3636055584_65a60426f8.jpg',
#  '/content/Flicker8k_Dataset/2465691083_894fc48af6.jpg',
#  '/content/Flicker8k_Dataset/222759342_98294380fc.jpg',
#  '/content/Flicker8k_Dataset/3533145793_5d69f72e41.jpg',
#  '/content/Flicker8k_Dataset/470903027_489cc507de.jpg',
#  '/content/Flicker8k_Dataset/2569643552_23696a9ba5.jpg',
#  '/content/Flicker8k_Dataset/3218481970_1fa627b3da.jpg',
#  '/content/Flicker8k_Dataset/3550459890_161f436c8d.jpg',
#  '/content/Flicker8k_Dataset/3405720825_b6991005eb.jpg',
#  '/content/Flicker8k_Dataset/527272653_8a5bd818e5.jpg',
#  '/content/Flicker8k_Dataset/3098707588_5096d20397.jpg',
#  '/content/Flicker8k_Dataset/2339946012_06bd480ab8.jpg',
#  '/content/Flicker8k_Dataset/3025334206_76888792e5.jpg',
#  '/content/Flicker8k_Dataset/2089539651_9e518ec7de.jpg',
#  '/content/Flicker8k_Dataset/2467856402_0490413d38.jpg',
#  '/content/Flicker8k_Dataset/1884727806_d84f209868.jpg',
#  '/content/Flicker8k_Dataset/3513265399_a32e8cfd18.jpg',
#  '/content/Flicker8k_Dataset/3148193539_de9dd48fc8.jpg',
#  '/content/Flicker8k_Dataset/544122267_e9e0100bc5.jpg',
#  '/content/Flicker8k_Dataset/1798209205_77dbf525b0.jpg',
#  '/content/Flicker8k_Dataset/3657503733_9888ccf05e.jpg',
#  '/content/Flicker8k_Dataset/871290666_4877e128c0.jpg',
#  '/content/Flicker8k_Dataset/2377460540_8cfb62463a.jpg',
#  '/content/Flicker8k_Dataset/1499495021_d295ce577c.jpg',
#  '/content/Flicker8k_Dataset/1473080948_bae2925dc8.jpg',
#  '/content/Flicker8k_Dataset/3765374230_cb1bbee0cb.jpg',
#  '/content/Flicker8k_Dataset/3584603849_6cfd9af7dd.jpg',
#  '/content/Flicker8k_Dataset/2987576188_f82304f394.jpg',
#  '/content/Flicker8k_Dataset/2039457436_fc30f5e1ce.jpg',
#  '/content/Flicker8k_Dataset/2040941056_7f5fd50794.jpg',
#  '/content/Flicker8k_Dataset/2126950128_74a4882658.jpg',
#  '/content/Flicker8k_Dataset/3579842996_3a62ec1bc7.jpg',
#  '/content/Flicker8k_Dataset/3240090389_97a8c5d386.jpg',
#  '/content/Flicker8k_Dataset/291952021_f111b0fb3d.jpg',
#  '/content/Flicker8k_Dataset/3138562460_44227a35cf.jpg',
#  '/content/Flicker8k_Dataset/956164675_9ee084364e.jpg',
#  '/content/Flicker8k_Dataset/2735979477_eef7c680f9.jpg',
#  '/content/Flicker8k_Dataset/2053006423_6adf69ca67.jpg',
#  '/content/Flicker8k_Dataset/3597921737_3fd1d0665b.jpg',
#  '/content/Flicker8k_Dataset/252578659_9e404b6430.jpg',
#  '/content/Flicker8k_Dataset/3604383863_5e387cb8e6.jpg',
#  '/content/Flicker8k_Dataset/3174196837_800689a2f3.jpg',
#  '/content/Flicker8k_Dataset/3252588185_3210fe94be.jpg',
#  '/content/Flicker8k_Dataset/3166969425_b5ace2f9c2.jpg',
#  '/content/Flicker8k_Dataset/268654674_d29e00b3d0.jpg',
#  '/content/Flicker8k_Dataset/2872743471_30e0d1a90a.jpg',
#  '/content/Flicker8k_Dataset/3639547922_0b00fed5cd.jpg',
#  '/content/Flicker8k_Dataset/1457762320_7fe121b285.jpg',
#  '/content/Flicker8k_Dataset/1975531316_8b00eeaaf7.jpg',
#  '/content/Flicker8k_Dataset/3133403457_95dfe11da1.jpg',
#  '/content/Flicker8k_Dataset/371522748_dc557bcd6c.jpg',
#  '/content/Flicker8k_Dataset/2565618804_8d7ed87389.jpg',
#  '/content/Flicker8k_Dataset/1342766791_1e72f92455.jpg',
#  '/content/Flicker8k_Dataset/3130970054_04a3865c43.jpg',
#  '/content/Flicker8k_Dataset/2751466788_4fab701cc3.jpg',
#  '/content/Flicker8k_Dataset/3249014584_21dd9ddd9d.jpg',
#  '/content/Flicker8k_Dataset/512991147_dc48e6839c.jpg',
#  '/content/Flicker8k_Dataset/242558556_12f4d1cabc.jpg',
#  '/content/Flicker8k_Dataset/2376878930_dd3e7cc544.jpg',
#  '/content/Flicker8k_Dataset/124195430_d14028660f.jpg',
#  '/content/Flicker8k_Dataset/3603870481_1ebc696d91.jpg',
#  '/content/Flicker8k_Dataset/1771490732_0ab5f029ac.jpg',
#  '/content/Flicker8k_Dataset/1732217138_aa0199ef87.jpg',
#  '/content/Flicker8k_Dataset/1576185717_f841ddc3da.jpg',
#  '/content/Flicker8k_Dataset/2250555512_71670078f5.jpg',
#  '/content/Flicker8k_Dataset/2442243868_abe8f74fb4.jpg',
#  '/content/Flicker8k_Dataset/1394396709_65040d97ab.jpg',
#  '/content/Flicker8k_Dataset/397725001_e51f7c391c.jpg',
#  '/content/Flicker8k_Dataset/2337919839_df83827fa0.jpg',
#  '/content/Flicker8k_Dataset/2534652796_c8a23288ab.jpg',
#  '/content/Flicker8k_Dataset/539705321_99406e5820.jpg',
#  '/content/Flicker8k_Dataset/2854291706_d4c31dbf56.jpg',
#  '/content/Flicker8k_Dataset/3608400551_d6f7965308.jpg',
#  '/content/Flicker8k_Dataset/380527679_574749123d.jpg',
#  '/content/Flicker8k_Dataset/2561334141_0aacefa5e7.jpg',
#  '/content/Flicker8k_Dataset/245442617_407eba1e98.jpg',
#  '/content/Flicker8k_Dataset/2222559267_6fd31e3941.jpg',
#  '/content/Flicker8k_Dataset/3641999223_942f8198cc.jpg',
#  '/content/Flicker8k_Dataset/3426789838_8771f0ed56.jpg',
#  '/content/Flicker8k_Dataset/2899089320_3e7f6bbaca.jpg',
#  '/content/Flicker8k_Dataset/2181724497_dbb7fcb0a9.jpg',
#  '/content/Flicker8k_Dataset/3649224118_abe73c672c.jpg',
#  '/content/Flicker8k_Dataset/2298283771_fb21a4217e.jpg',
#  '/content/Flicker8k_Dataset/2282600972_c22d1e03c7.jpg',
#  '/content/Flicker8k_Dataset/418796494_bdb441de42.jpg',
#  '/content/Flicker8k_Dataset/365274901_576b0f8241.jpg',
#  '/content/Flicker8k_Dataset/733964952_69f011a6c4.jpg',
#  '/content/Flicker8k_Dataset/3374759363_d6f7a0df41.jpg',
#  '/content/Flicker8k_Dataset/296873864_4de75de261.jpg',
#  '/content/Flicker8k_Dataset/2860372882_e0ef4131d4.jpg',
#  '/content/Flicker8k_Dataset/3517362674_0f5296de19.jpg',
#  '/content/Flicker8k_Dataset/2206594874_5e0087c6b7.jpg',
#  '/content/Flicker8k_Dataset/3084010872_cbc3ea8239.jpg',
#  '/content/Flicker8k_Dataset/2798880731_4f51634374.jpg',
#  '/content/Flicker8k_Dataset/512634877_d7ad8c8329.jpg',
#  '/content/Flicker8k_Dataset/3619630328_2d0865b6f4.jpg',
#  '/content/Flicker8k_Dataset/3105315670_5f86f73753.jpg',
#  '/content/Flicker8k_Dataset/1087168168_70280d024a.jpg',
#  '/content/Flicker8k_Dataset/3143953179_1c08c023a5.jpg',
#  '/content/Flicker8k_Dataset/3050114829_18bc5a6d7c.jpg',
#  '/content/Flicker8k_Dataset/3529721084_4b405baf54.jpg',
#  '/content/Flicker8k_Dataset/3409740108_1505489537.jpg',
#  '/content/Flicker8k_Dataset/445148321_9f2f3ac711.jpg',
#  '/content/Flicker8k_Dataset/1904112245_549e47c8aa.jpg',
#  '/content/Flicker8k_Dataset/3527682660_c5e9fa644a.jpg',
#  '/content/Flicker8k_Dataset/2404488732_ca1bbdacc2.jpg',
#  '/content/Flicker8k_Dataset/1277185009_06478dd457.jpg',
#  '/content/Flicker8k_Dataset/2886533440_dfa832f2fa.jpg',
#  '/content/Flicker8k_Dataset/3402081035_a54cfab1d9.jpg',
#  '/content/Flicker8k_Dataset/314904143_5a216a192b.jpg',
#  '/content/Flicker8k_Dataset/3183195185_cd0ff994a1.jpg',
#  '/content/Flicker8k_Dataset/2315867011_fc5fc9fa6d.jpg',
#  '/content/Flicker8k_Dataset/2209888959_d636b1be0b.jpg',
#  '/content/Flicker8k_Dataset/3413669228_ec64efeb34.jpg',
#  '/content/Flicker8k_Dataset/2932498509_27cb0038ec.jpg',
#  '/content/Flicker8k_Dataset/2949353587_64c54e9589.jpg',
#  '/content/Flicker8k_Dataset/3304030264_da3dd18c7b.jpg',
#  '/content/Flicker8k_Dataset/2215165918_2bf5b659dd.jpg',
#  '/content/Flicker8k_Dataset/933118213_b35b0b62a7.jpg',
#  '/content/Flicker8k_Dataset/2952320230_26601173be.jpg',
#  '/content/Flicker8k_Dataset/1289142574_2bd6a082dd.jpg',
#  '/content/Flicker8k_Dataset/3278811919_d5a3432af6.jpg',
#  '/content/Flicker8k_Dataset/3573202338_f43dd22d28.jpg',
#  '/content/Flicker8k_Dataset/2756636539_cc1eacbf4a.jpg',
#  '/content/Flicker8k_Dataset/3729405438_6e79077ab2.jpg',
#  '/content/Flicker8k_Dataset/3429142249_d09a32e291.jpg',
#  '/content/Flicker8k_Dataset/3169777863_d745865784.jpg',
#  '/content/Flicker8k_Dataset/401476986_73918145a3.jpg',
#  '/content/Flicker8k_Dataset/3357416302_fcfcdd7b86.jpg',
#  '/content/Flicker8k_Dataset/3708839890_ed448012cf.jpg',
#  '/content/Flicker8k_Dataset/3351493005_6e5030f596.jpg',
#  '/content/Flicker8k_Dataset/2768972186_92787cd523.jpg',
#  '/content/Flicker8k_Dataset/521658170_a837af87e9.jpg',
#  '/content/Flicker8k_Dataset/3690431163_1d81e19549.jpg',
#  '/content/Flicker8k_Dataset/3662871327_b128d25f04.jpg',
#  '/content/Flicker8k_Dataset/3323514651_3efdbd63ed.jpg',
#  '/content/Flicker8k_Dataset/2548777800_d7b9cf1c2b.jpg',
#  '/content/Flicker8k_Dataset/3272071680_648a99f7d2.jpg',
#  '/content/Flicker8k_Dataset/532396029_ce125bda3f.jpg',
#  '/content/Flicker8k_Dataset/3033686219_452b172ab0.jpg',
#  '/content/Flicker8k_Dataset/1363924449_487f0733df.jpg',
#  '/content/Flicker8k_Dataset/3532192208_64b069d05d.jpg',
#  '/content/Flicker8k_Dataset/1151466868_3bc4d9580b.jpg',
#  '/content/Flicker8k_Dataset/1525153022_06c48dbe52.jpg',
#  '/content/Flicker8k_Dataset/2752809449_632cd991b3.jpg',
#  '/content/Flicker8k_Dataset/3090957866_f1b2b7f214.jpg',
#  '/content/Flicker8k_Dataset/3290465391_258429e2f9.jpg',
#  '/content/Flicker8k_Dataset/394161692_2576920777.jpg',
#  '/content/Flicker8k_Dataset/3667908724_65c7d112f2.jpg',
#  '/content/Flicker8k_Dataset/2423292784_166ee54e0b.jpg',
#  '/content/Flicker8k_Dataset/519061891_320061864e.jpg',
#  '/content/Flicker8k_Dataset/336551615_a01418bc53.jpg',
#  '/content/Flicker8k_Dataset/1932161768_996eadac87.jpg',
#  '/content/Flicker8k_Dataset/2277081067_d2b4c98bce.jpg',
#  '/content/Flicker8k_Dataset/2156726763_034ecd2e39.jpg',
#  '/content/Flicker8k_Dataset/2135360514_7dcb9ed796.jpg',
#  '/content/Flicker8k_Dataset/641893280_36fd6e886a.jpg',
#  '/content/Flicker8k_Dataset/3346614841_698f9aa486.jpg',
#  '/content/Flicker8k_Dataset/2766765386_4c0beb939d.jpg',
#  '/content/Flicker8k_Dataset/1676601498_7d59327523.jpg',
#  '/content/Flicker8k_Dataset/3547647914_4dd56a8c1b.jpg',
#  '/content/Flicker8k_Dataset/2533076864_d799996433.jpg',
#  '/content/Flicker8k_Dataset/2245348304_08bc5642f1.jpg',
#  '/content/Flicker8k_Dataset/3079917032_3cfacb2fd7.jpg',
#  '/content/Flicker8k_Dataset/3476709230_6439305bf2.jpg',
#  '/content/Flicker8k_Dataset/2531837969_6f28637811.jpg',
#  '/content/Flicker8k_Dataset/247097023_e656d5854d.jpg',
#  '/content/Flicker8k_Dataset/128912885_8350d277a4.jpg',
#  '/content/Flicker8k_Dataset/2510560080_1439fe32f2.jpg',
#  '/content/Flicker8k_Dataset/1794818900_e0ffdd268e.jpg',
#  '/content/Flicker8k_Dataset/2979914158_5906470b8f.jpg',
#  '/content/Flicker8k_Dataset/823697339_aadbeef495.jpg',
#  '/content/Flicker8k_Dataset/2710698257_2e4ca8dd44.jpg',
#  '/content/Flicker8k_Dataset/312427606_defa0dfaa8.jpg',
#  '/content/Flicker8k_Dataset/3351111378_b5d80783a1.jpg',
#  '/content/Flicker8k_Dataset/428408242_b32faf2240.jpg',
#  '/content/Flicker8k_Dataset/1231229740_8dcbf80bfb.jpg',
#  '/content/Flicker8k_Dataset/878758390_dd2cdc42f6.jpg',
#  '/content/Flicker8k_Dataset/2632111399_b3c1630f8e.jpg',
#  '/content/Flicker8k_Dataset/3520617304_e53d37f0af.jpg',
#  '/content/Flicker8k_Dataset/412056525_191724b058.jpg',
#  '/content/Flicker8k_Dataset/236095034_c983bdfbbf.jpg',
#  '/content/Flicker8k_Dataset/2991375936_bf4b0a7dc0.jpg',
#  '/content/Flicker8k_Dataset/197924859_f6e39a7dfa.jpg',
#  '/content/Flicker8k_Dataset/2173312932_269f9786fc.jpg',
#  '/content/Flicker8k_Dataset/2447289477_e888df561d.jpg',
#  '/content/Flicker8k_Dataset/3047749814_621ed0786b.jpg',
#  '/content/Flicker8k_Dataset/2715289538_d77c8d0a85.jpg',
#  '/content/Flicker8k_Dataset/2302747917_aa0300eb68.jpg',
#  '/content/Flicker8k_Dataset/1252396628_eb81d3905b.jpg',
#  '/content/Flicker8k_Dataset/3659090958_a56913ca68.jpg',
#  '/content/Flicker8k_Dataset/1445754124_647168f211.jpg',
#  '/content/Flicker8k_Dataset/3391924827_53b31542ce.jpg',
#  '/content/Flicker8k_Dataset/3088399255_1bd9a6aa04.jpg',
#  '/content/Flicker8k_Dataset/3191805046_77c334b506.jpg',
#  '/content/Flicker8k_Dataset/3286045254_696c6b15bd.jpg',
#  '/content/Flicker8k_Dataset/439492931_a96d590e40.jpg',
#  '/content/Flicker8k_Dataset/3126225245_96cd2c053f.jpg',
#  '/content/Flicker8k_Dataset/2070831281_dc04b3e15d.jpg',
#  '/content/Flicker8k_Dataset/3272847211_9e8a4f8308.jpg',
#  '/content/Flicker8k_Dataset/3636126441_5617c89aaa.jpg',
#  '/content/Flicker8k_Dataset/408233586_f2c1be3ce1.jpg',
#  '/content/Flicker8k_Dataset/58363928_6f7074608c.jpg',
#  '/content/Flicker8k_Dataset/3375843443_8d9b242aa5.jpg',
#  '/content/Flicker8k_Dataset/241346885_f519ece460.jpg',
#  '/content/Flicker8k_Dataset/3595080592_5fd55570e5.jpg',
#  '/content/Flicker8k_Dataset/2091171488_c8512fec76.jpg',
#  '/content/Flicker8k_Dataset/3658733605_fbcf570843.jpg',
#  '/content/Flicker8k_Dataset/2927878881_90b42fc444.jpg',
#  '/content/Flicker8k_Dataset/1115565519_d976d4b1f1.jpg',
#  '/content/Flicker8k_Dataset/216172386_9ac5356dae.jpg',
#  '/content/Flicker8k_Dataset/3549408779_4d453db080.jpg',
#  '/content/Flicker8k_Dataset/3360823754_90967276ec.jpg',
#  '/content/Flicker8k_Dataset/2593695271_4d9cc9bd6f.jpg',
#  '/content/Flicker8k_Dataset/2688902319_52ceaf4a2a.jpg',
#  '/content/Flicker8k_Dataset/2456030728_d3d147e774.jpg',
#  '/content/Flicker8k_Dataset/2436398074_8737f40869.jpg',
#  '/content/Flicker8k_Dataset/923550133_ac9d7a2932.jpg',
#  '/content/Flicker8k_Dataset/1397295388_8a5b6b525d.jpg',
#  '/content/Flicker8k_Dataset/483136916_16976f4902.jpg',
#  '/content/Flicker8k_Dataset/979201222_75b6456d34.jpg',
#  '/content/Flicker8k_Dataset/3373243733_9aba7740ed.jpg',
#  '/content/Flicker8k_Dataset/3222749441_3bdfe088e3.jpg',
#  '/content/Flicker8k_Dataset/3040051410_6205682ba3.jpg',
#  '/content/Flicker8k_Dataset/2453318633_550228acd4.jpg',
#  '/content/Flicker8k_Dataset/2279496715_8ef3ee6edb.jpg',
#  '/content/Flicker8k_Dataset/3636247381_65ccf8f106.jpg',
#  '/content/Flicker8k_Dataset/1350948838_fdebe4ff65.jpg',
#  '/content/Flicker8k_Dataset/1067180831_a59dc64344.jpg',
#  '/content/Flicker8k_Dataset/161669933_3e7d8c7e2c.jpg',
#  '/content/Flicker8k_Dataset/2090327868_9f99e2740d.jpg',
#  '/content/Flicker8k_Dataset/1994416869_4dd769a806.jpg',
#  '/content/Flicker8k_Dataset/478209058_21e2c37c73.jpg',
#  '/content/Flicker8k_Dataset/3626964430_cb5c7e5acc.jpg',
#  '/content/Flicker8k_Dataset/2354456107_bf5c766a05.jpg',
#  '/content/Flicker8k_Dataset/160541986_d5be2ab4c1.jpg',
#  '/content/Flicker8k_Dataset/2782480767_064c95eff2.jpg',
#  '/content/Flicker8k_Dataset/2231847779_1148d1c919.jpg',
#  '/content/Flicker8k_Dataset/111537222_07e56d5a30.jpg',
#  '/content/Flicker8k_Dataset/3091382602_60b9b53ed1.jpg',
#  '/content/Flicker8k_Dataset/2599903773_0f724d8f63.jpg',
#  '/content/Flicker8k_Dataset/3006095077_1992b677f8.jpg',
#  '/content/Flicker8k_Dataset/2524084967_a5e011b73d.jpg',
#  '/content/Flicker8k_Dataset/2528552898_9e49a7033f.jpg',
#  '/content/Flicker8k_Dataset/3176072448_b84c99cf7f.jpg',
#  '/content/Flicker8k_Dataset/1356543628_c13ebe38fb.jpg',
#  '/content/Flicker8k_Dataset/2676648667_cb055b4fc6.jpg',
#  '/content/Flicker8k_Dataset/3339916063_63b960ed46.jpg',
#  '/content/Flicker8k_Dataset/1131804997_177c3c0640.jpg',
#  '/content/Flicker8k_Dataset/3649382413_58a4b1efe8.jpg',
#  '/content/Flicker8k_Dataset/3636491114_ab34dac833.jpg',
#  '/content/Flicker8k_Dataset/3466353172_deb128bbb0.jpg',
#  '/content/Flicker8k_Dataset/186890605_ddff5b694e.jpg',
#  '/content/Flicker8k_Dataset/2607383384_d9ce9de793.jpg',
#  '/content/Flicker8k_Dataset/3271178748_630d269811.jpg',
#  '/content/Flicker8k_Dataset/2629445284_83390e83af.jpg',
#  '/content/Flicker8k_Dataset/475042270_719ebe6c48.jpg',
#  '/content/Flicker8k_Dataset/2846037553_1a1de50709.jpg',
#  '/content/Flicker8k_Dataset/2355578735_286af5b202.jpg',
#  '/content/Flicker8k_Dataset/3543600125_223747ef4c.jpg',
#  '/content/Flicker8k_Dataset/3528966521_2e871ff6a1.jpg',
#  '/content/Flicker8k_Dataset/1363843090_9425d93064.jpg',
#  '/content/Flicker8k_Dataset/2572101672_4d699c8713.jpg',
#  '/content/Flicker8k_Dataset/2139519215_8ca16dd192.jpg',
#  '/content/Flicker8k_Dataset/1142283988_6b227c5231.jpg',
#  '/content/Flicker8k_Dataset/2214847438_4993210d4c.jpg',
#  '/content/Flicker8k_Dataset/334737767_7f344eee16.jpg',
#  '/content/Flicker8k_Dataset/2592019072_a6c0090da4.jpg',
#  '/content/Flicker8k_Dataset/3322389758_394c990b6a.jpg',
#  '/content/Flicker8k_Dataset/3589267801_5a222e3a60.jpg',
#  '/content/Flicker8k_Dataset/2049646140_d0de01e3c4.jpg',
#  '/content/Flicker8k_Dataset/1290894194_8a4ffdc7eb.jpg',
#  '/content/Flicker8k_Dataset/374103966_2987706be1.jpg',
#  '/content/Flicker8k_Dataset/150582765_bad8dec237.jpg',
#  '/content/Flicker8k_Dataset/2686432878_0697dbc048.jpg',
#  '/content/Flicker8k_Dataset/2685139184_4ff45e0f76.jpg',
#  '/content/Flicker8k_Dataset/359173181_a75c950aeb.jpg',
#  '/content/Flicker8k_Dataset/241109594_3cb90fe2a3.jpg',
#  '/content/Flicker8k_Dataset/3673035152_da7ed916d9.jpg',
#  '/content/Flicker8k_Dataset/3558796959_fc4450be56.jpg',
#  '/content/Flicker8k_Dataset/2923825744_ca125353f0.jpg',
#  '/content/Flicker8k_Dataset/1294578091_2ad02fea91.jpg',
#  '/content/Flicker8k_Dataset/3593222804_c187808ac3.jpg',
#  '/content/Flicker8k_Dataset/2030781555_b7ff7be28f.jpg',
#  '/content/Flicker8k_Dataset/2800758232_d7fa598065.jpg',
#  '/content/Flicker8k_Dataset/2543247940_083f1b7969.jpg',
#  '/content/Flicker8k_Dataset/3296500180_0d7a6650dc.jpg',
#  '/content/Flicker8k_Dataset/362316425_bda238b4de.jpg',
#  '/content/Flicker8k_Dataset/3442138291_3e75f4bdb8.jpg',
#  '/content/Flicker8k_Dataset/411011549_1298d2b4d2.jpg',
#  '/content/Flicker8k_Dataset/3539817989_5353062a39.jpg',
#  '/content/Flicker8k_Dataset/2880051254_e0ca96b6be.jpg',
#  '/content/Flicker8k_Dataset/3551003620_0b02d76f65.jpg',
#  '/content/Flicker8k_Dataset/322050103_145f7233c6.jpg',
#  '/content/Flicker8k_Dataset/251056963_c8b67f0107.jpg',
#  '/content/Flicker8k_Dataset/3591094476_b61acd63d6.jpg',
#  '/content/Flicker8k_Dataset/3737492755_bcfb800ed1.jpg',
#  '/content/Flicker8k_Dataset/2071309418_1d7580b0f0.jpg',
#  '/content/Flicker8k_Dataset/282116218_7fd7583d6e.jpg',
#  '/content/Flicker8k_Dataset/2877159456_ea4a46b0d2.jpg',
#  '/content/Flicker8k_Dataset/1784309115_0ad6791146.jpg',
#  '/content/Flicker8k_Dataset/308014594_f1d5e75507.jpg',
#  '/content/Flicker8k_Dataset/3606942887_1159d92548.jpg',
#  '/content/Flicker8k_Dataset/3229519418_040f05ced1.jpg',
#  '/content/Flicker8k_Dataset/542269487_5d77b363eb.jpg',
#  '/content/Flicker8k_Dataset/3744832122_2f4febdff6.jpg',
#  '/content/Flicker8k_Dataset/3329777647_5e1fd503ac.jpg',
#  '/content/Flicker8k_Dataset/3050976633_9c25cf6fa0.jpg',
#  '/content/Flicker8k_Dataset/3082934678_58534e9d2c.jpg',
#  '/content/Flicker8k_Dataset/3423225860_16e26eef74.jpg',
#  '/content/Flicker8k_Dataset/1429814475_0b592b9995.jpg',
#  '/content/Flicker8k_Dataset/2588625139_fdf6610218.jpg',
#  '/content/Flicker8k_Dataset/358559906_d5f3f584f4.jpg',
#  '/content/Flicker8k_Dataset/3366904106_e996320d20.jpg',
#  '/content/Flicker8k_Dataset/3185695861_86152b2755.jpg',
#  '/content/Flicker8k_Dataset/3585117340_73e96b6173.jpg',
#  '/content/Flicker8k_Dataset/3527524436_a54aca78a9.jpg',
#  '/content/Flicker8k_Dataset/3544573946_e03aebbfde.jpg',
#  '/content/Flicker8k_Dataset/380590140_25b9889772.jpg',
#  '/content/Flicker8k_Dataset/3118505332_b0792489b5.jpg',
#  '/content/Flicker8k_Dataset/3328397409_092de2bd32.jpg',
#  '/content/Flicker8k_Dataset/410413536_11f1127c46.jpg',
#  '/content/Flicker8k_Dataset/2445654384_4ee3e486e1.jpg',
#  '/content/Flicker8k_Dataset/3048380686_732db55281.jpg',
#  '/content/Flicker8k_Dataset/3064716525_b8418d4946.jpg',
#  '/content/Flicker8k_Dataset/3681172959_6674c118d2.jpg',
#  '/content/Flicker8k_Dataset/2332540384_4cf26406a9.jpg',
#  '/content/Flicker8k_Dataset/2603334363_cfa32c4482.jpg',
#  '/content/Flicker8k_Dataset/3465473743_7da0c5d973.jpg',
#  '/content/Flicker8k_Dataset/260231029_966e2f1727.jpg',
#  '/content/Flicker8k_Dataset/2428797297_7fc3c862db.jpg',
#  '/content/Flicker8k_Dataset/2434074318_e35a567220.jpg',
#  '/content/Flicker8k_Dataset/3433470650_a8b1c27173.jpg',
#  '/content/Flicker8k_Dataset/3724623861_2bb6c23641.jpg',
#  '/content/Flicker8k_Dataset/1439282131_3814d6ae04.jpg',
#  '/content/Flicker8k_Dataset/1433397131_8634fa6664.jpg',
#  '/content/Flicker8k_Dataset/3056530884_27766059bc.jpg',
#  '/content/Flicker8k_Dataset/3659686168_49c3abcee1.jpg',
#  '/content/Flicker8k_Dataset/2579268572_d78f8436cb.jpg',
#  '/content/Flicker8k_Dataset/2259336826_0cb294e1f7.jpg',
#  '/content/Flicker8k_Dataset/3084380974_268a0f9236.jpg',
#  '/content/Flicker8k_Dataset/480200554_6155e9dfeb.jpg',
#  '/content/Flicker8k_Dataset/3278777548_290b881018.jpg',
#  '/content/Flicker8k_Dataset/3677302645_8cd3fac70d.jpg',
#  '/content/Flicker8k_Dataset/3454988449_1de1ef4f20.jpg',
#  '/content/Flicker8k_Dataset/2127207912_9298824e66.jpg',
#  '/content/Flicker8k_Dataset/2508249781_36e9282423.jpg',
#  '/content/Flicker8k_Dataset/2443229844_277cded27d.jpg',
#  '/content/Flicker8k_Dataset/895502702_5170ada2ee.jpg',
#  '/content/Flicker8k_Dataset/345284642_77dded0907.jpg',
#  '/content/Flicker8k_Dataset/3131632154_098f86f4cb.jpg',
#  '/content/Flicker8k_Dataset/327997381_55f90dc834.jpg',
#  '/content/Flicker8k_Dataset/2713897716_c8cd610360.jpg',
#  '/content/Flicker8k_Dataset/2261346505_302c67951d.jpg',
#  '/content/Flicker8k_Dataset/2540750172_070250ece5.jpg',
#  '/content/Flicker8k_Dataset/2708176152_1634cb754d.jpg',
#  '/content/Flicker8k_Dataset/2228167286_7089ab236a.jpg',
#  '/content/Flicker8k_Dataset/3251460982_4578a568bb.jpg',
#  '/content/Flicker8k_Dataset/495014499_8fd065cfd9.jpg',
#  '/content/Flicker8k_Dataset/862054277_34b5a6f401.jpg',
#  '/content/Flicker8k_Dataset/3110174991_a4b05f8a46.jpg',
#  '/content/Flicker8k_Dataset/2836325261_a3bf5c59be.jpg',
#  '/content/Flicker8k_Dataset/2709275718_73fcf08c23.jpg',
#  '/content/Flicker8k_Dataset/1153704539_542f7aa3a5.jpg',
#  '/content/Flicker8k_Dataset/3697003897_d8ac13be9a.jpg',
#  '/content/Flicker8k_Dataset/359082432_c1fd5aa2d6.jpg',
#  '/content/Flicker8k_Dataset/442918418_0f29c97fa9.jpg',
#  '/content/Flicker8k_Dataset/455611732_d65bf3e976.jpg',
#  '/content/Flicker8k_Dataset/2760715910_87c7bdeb87.jpg',
#  '/content/Flicker8k_Dataset/3595216998_0a19efebd0.jpg',
#  '/content/Flicker8k_Dataset/520491467_54cbc0a866.jpg',
#  '/content/Flicker8k_Dataset/2109479807_eec8d72ca7.jpg',
#  '/content/Flicker8k_Dataset/3249597269_935e0a375a.jpg',
#  '/content/Flicker8k_Dataset/1859726819_9a793b3b44.jpg',
#  '/content/Flicker8k_Dataset/230016181_0c52b95304.jpg',
#  '/content/Flicker8k_Dataset/534200447_b0f3ff02be.jpg',
#  '/content/Flicker8k_Dataset/2873431806_86a56cdae8.jpg',
#  '/content/Flicker8k_Dataset/3328247381_a9f7fb4898.jpg',
#  '/content/Flicker8k_Dataset/41999070_838089137e.jpg',
#  '/content/Flicker8k_Dataset/3248408149_41a8dd90d3.jpg',
#  '/content/Flicker8k_Dataset/2657663775_bc98bf67ac.jpg',
#  '/content/Flicker8k_Dataset/3333826465_9c84c1b3c6.jpg',
#  '/content/Flicker8k_Dataset/2611651553_61f859837e.jpg',
#  '/content/Flicker8k_Dataset/2195419145_36722e8d54.jpg',
#  '/content/Flicker8k_Dataset/3264350290_f50494e835.jpg',
#  '/content/Flicker8k_Dataset/2832487464_2d30634e1e.jpg',
#  '/content/Flicker8k_Dataset/502783522_3656f27014.jpg',
#  '/content/Flicker8k_Dataset/3193335577_9bdbaf9f70.jpg',
#  '/content/Flicker8k_Dataset/2303016989_0deb96c8d9.jpg',
#  '/content/Flicker8k_Dataset/3116379964_86986750af.jpg',
#  '/content/Flicker8k_Dataset/2994104606_bc2df6c1f4.jpg',
#  '/content/Flicker8k_Dataset/3373069977_bc73e9e409.jpg',
#  '/content/Flicker8k_Dataset/241345656_861aacefde.jpg',
#  '/content/Flicker8k_Dataset/3339319023_5dcc3ef81a.jpg',
#  '/content/Flicker8k_Dataset/241345770_9f8aa6723c.jpg',
#  '/content/Flicker8k_Dataset/782017931_75d92bb7a4.jpg',
#  '/content/Flicker8k_Dataset/1280147517_98767ca3b3.jpg',
#  '/content/Flicker8k_Dataset/2691966747_cfa154982b.jpg',
#  '/content/Flicker8k_Dataset/3482474257_a88bfe5c57.jpg',
#  '/content/Flicker8k_Dataset/3203872773_6c30f64be3.jpg',
#  '/content/Flicker8k_Dataset/3319388517_5609ae9805.jpg',
#  '/content/Flicker8k_Dataset/3201666946_04fe837aff.jpg',
#  '/content/Flicker8k_Dataset/422756764_e7eaac76bf.jpg',
#  '/content/Flicker8k_Dataset/1424237335_b3be9920ba.jpg',
#  '/content/Flicker8k_Dataset/2766926202_4201bf2bf9.jpg',
#  '/content/Flicker8k_Dataset/439916996_1ddb9dc8e7.jpg',
#  '/content/Flicker8k_Dataset/478592803_f57cc9c461.jpg',
#  '/content/Flicker8k_Dataset/3117562746_62f57a02b5.jpg',
#  '/content/Flicker8k_Dataset/860928274_744d14f198.jpg',
#  '/content/Flicker8k_Dataset/3397803103_8a46d716f4.jpg',
#  '/content/Flicker8k_Dataset/2443512473_6f5a22eb42.jpg',
#  '/content/Flicker8k_Dataset/2500826039_165e75b20c.jpg',
#  '/content/Flicker8k_Dataset/2528489543_546c1ca81f.jpg',
#  '/content/Flicker8k_Dataset/1876536922_8fdf8d7028.jpg',
#  '/content/Flicker8k_Dataset/306318683_5f1f875191.jpg',
#  '/content/Flicker8k_Dataset/512045825_1be2083922.jpg',
#  '/content/Flicker8k_Dataset/279230262_e541f9b670.jpg',
#  '/content/Flicker8k_Dataset/3323528927_7b21081271.jpg',
#  '/content/Flicker8k_Dataset/446291803_2fd4641b99.jpg',
#  '/content/Flicker8k_Dataset/2403544744_cba152f5c1.jpg',
#  '/content/Flicker8k_Dataset/2065875490_a46b58c12b.jpg',
#  '/content/Flicker8k_Dataset/361183669_52be9662b9.jpg',
#  '/content/Flicker8k_Dataset/2545192257_142fe9e2de.jpg',
#  '/content/Flicker8k_Dataset/276699720_fe6718fd03.jpg',
#  '/content/Flicker8k_Dataset/307994435_592f933a6d.jpg',
#  '/content/Flicker8k_Dataset/3251234434_d01e25a50a.jpg',
#  '/content/Flicker8k_Dataset/3569329986_1f468729b2.jpg',
#  '/content/Flicker8k_Dataset/2395967330_7e6ea404f6.jpg',
#  '/content/Flicker8k_Dataset/1579198375_84b18e003a.jpg',
#  '/content/Flicker8k_Dataset/397601572_9587a39291.jpg',
#  '/content/Flicker8k_Dataset/3433567526_00b5a70319.jpg',
#  '/content/Flicker8k_Dataset/538825260_a4a8784b75.jpg',
#  '/content/Flicker8k_Dataset/414568315_5adcfc23c0.jpg',
#  '/content/Flicker8k_Dataset/3584406900_039f30b34c.jpg',
#  '/content/Flicker8k_Dataset/384465370_9918873f9a.jpg',
#  '/content/Flicker8k_Dataset/2527163162_d0fb802992.jpg',
#  '/content/Flicker8k_Dataset/1354318519_2f9baed754.jpg',
#  '/content/Flicker8k_Dataset/2305437797_e6c3460190.jpg',
#  '/content/Flicker8k_Dataset/2275372714_017c269742.jpg',
#  '/content/Flicker8k_Dataset/2717686269_80c4b5ac9e.jpg',
#  '/content/Flicker8k_Dataset/2635908229_b9fc90d3fb.jpg',
#  '/content/Flicker8k_Dataset/3516653997_98ec551a67.jpg',
#  '/content/Flicker8k_Dataset/3217909454_7baa0edbb2.jpg',
#  '/content/Flicker8k_Dataset/783994497_4f6885454d.jpg',
#  '/content/Flicker8k_Dataset/1299459550_1fd5594fa2.jpg',
#  '/content/Flicker8k_Dataset/2797188545_aeb26c54c0.jpg',
#  '/content/Flicker8k_Dataset/3437693401_202afef348.jpg',
#  '/content/Flicker8k_Dataset/3377117696_af91f13058.jpg',
#  '/content/Flicker8k_Dataset/455856615_f6361d9253.jpg',
#  '/content/Flicker8k_Dataset/3239480519_22540b5016.jpg',
#  '/content/Flicker8k_Dataset/437054333_5c2761b8cd.jpg',
#  '/content/Flicker8k_Dataset/3415287719_3c776f370e.jpg',
#  '/content/Flicker8k_Dataset/3558683579_8fb36b55a6.jpg',
#  '/content/Flicker8k_Dataset/428483413_b9370baf72.jpg',
#  '/content/Flicker8k_Dataset/2266901263_4324af1f03.jpg',
#  '/content/Flicker8k_Dataset/3249738122_decde6c117.jpg',
#  '/content/Flicker8k_Dataset/405961988_fcfe97f31e.jpg',
#  '/content/Flicker8k_Dataset/3295671644_0e10891b6d.jpg',
#  '/content/Flicker8k_Dataset/2856524322_1d04452a21.jpg',
#  '/content/Flicker8k_Dataset/537628742_146f2c24f8.jpg',
#  '/content/Flicker8k_Dataset/360723732_23199af4bf.jpg',
#  '/content/Flicker8k_Dataset/290982269_79fc9f36dc.jpg',
#  '/content/Flicker8k_Dataset/3039209547_81cc93fbec.jpg',
#  '/content/Flicker8k_Dataset/285306009_f6ddabe687.jpg',
#  '/content/Flicker8k_Dataset/3118425885_f0cc035032.jpg',
#  '/content/Flicker8k_Dataset/3265209567_b3b9c8e0fe.jpg',
#  '/content/Flicker8k_Dataset/3073535022_4af81f360c.jpg',
#  '/content/Flicker8k_Dataset/3612485097_b706d950ed.jpg',
#  '/content/Flicker8k_Dataset/3549464203_8ab9c6160b.jpg',
#  '/content/Flicker8k_Dataset/3503471307_464a8f588c.jpg',
#  '/content/Flicker8k_Dataset/2504764590_cf017c2a6e.jpg',
#  '/content/Flicker8k_Dataset/2699733386_c346c87ea6.jpg',
#  '/content/Flicker8k_Dataset/2546667441_bbe87a6285.jpg',
#  '/content/Flicker8k_Dataset/1301140633_046e4e8010.jpg',
#  '/content/Flicker8k_Dataset/458735196_176e7df6b3.jpg',
#  '/content/Flicker8k_Dataset/3304712466_18cbdb85fe.jpg',
#  '/content/Flicker8k_Dataset/2721656220_5f4cda8bc1.jpg',
#  '/content/Flicker8k_Dataset/1253275679_e955fb7304.jpg',
#  '/content/Flicker8k_Dataset/3668984985_b60ceb2ae9.jpg',
#  '/content/Flicker8k_Dataset/3241726740_6d256d61ec.jpg',
#  '/content/Flicker8k_Dataset/310213587_778fe8fb5b.jpg',
#  '/content/Flicker8k_Dataset/2974501005_346f74e5d8.jpg',
#  '/content/Flicker8k_Dataset/3716277216_c04002be81.jpg',
#  '/content/Flicker8k_Dataset/3320209694_db579cb607.jpg',
#  '/content/Flicker8k_Dataset/3368865171_597d51cdd5.jpg',
#  '/content/Flicker8k_Dataset/124881487_36e668145d.jpg',
#  '/content/Flicker8k_Dataset/2701603045_6cbdc4ce7c.jpg',
#  '/content/Flicker8k_Dataset/2278766574_f71f1704a8.jpg',
#  '/content/Flicker8k_Dataset/347543966_b2053ae78c.jpg',
#  '/content/Flicker8k_Dataset/1143882946_1898d2eeb9.jpg',
#  '/content/Flicker8k_Dataset/2029280005_a19609c81a.jpg',
#  '/content/Flicker8k_Dataset/3231751379_10ebf7150c.jpg',
#  '/content/Flicker8k_Dataset/3069216757_c419b3898e.jpg',
#  '/content/Flicker8k_Dataset/3234719720_5bb2fc5ffa.jpg',
#  '/content/Flicker8k_Dataset/491964988_414b556228.jpg',
#  '/content/Flicker8k_Dataset/2474047296_fd9179d438.jpg',
#  '/content/Flicker8k_Dataset/3546891929_f31a99cd0d.jpg',
#  '/content/Flicker8k_Dataset/2355763034_9fb61a8165.jpg',
#  '/content/Flicker8k_Dataset/3065560742_f6e266ccd9.jpg',
#  '/content/Flicker8k_Dataset/265528702_8653eab9fa.jpg',
#  '/content/Flicker8k_Dataset/2687539673_d54a8dc613.jpg',
#  '/content/Flicker8k_Dataset/3067500667_0fce8f28d4.jpg',
#  '/content/Flicker8k_Dataset/2657484970_610e18144f.jpg',
#  '/content/Flicker8k_Dataset/407008823_bdd7fc6ed5.jpg',
#  '/content/Flicker8k_Dataset/3675825945_96b2916959.jpg',
#  '/content/Flicker8k_Dataset/1557838421_a33f2a4911.jpg',
#  '/content/Flicker8k_Dataset/544301311_5e7d69a517.jpg',
#  '/content/Flicker8k_Dataset/3624076529_9793655a21.jpg',
#  '/content/Flicker8k_Dataset/537479916_c033897fac.jpg',
#  '/content/Flicker8k_Dataset/2737729252_b3fd9c05b1.jpg',
#  '/content/Flicker8k_Dataset/267162122_c3437414ec.jpg',
#  '/content/Flicker8k_Dataset/2592711202_55f8c64495.jpg',
#  ...]

# %% [markdown]
# # Encode images into feature vectors

# %%
# Function to encode given image into a vector of size (2048, )
def encode_image(image):
    image = preprocess_image(image) # preprocess image
    feature_vector = model_new.predict(image) # Get encoding vector for image
    feature_vector = feature_vector.reshape(feature_vector.shape[1], ) # reshape from (1, 2048) to (2048, )
    return feature_vector


# To encode all train images
start_train = time()
encoding_train = {}
for idx,img in enumerate(train_img_name):
    if( (idx+1)%500 == 0):
        print('Train images encoded ',idx+1)
    encoding_train[img] = encode_image(img)
print("** Time taken for encoding train images {} seconds **".format(time()-start_train))


# To encode all test images
start_test = time()
encoding_test = {}
for idx,img in enumerate(test_img_name):
    if( (idx+1)%200 == 0):
        print('Test images encoded ',idx+1)
    encoding_test[img] = encode_image(img)
print("** Time taken for encoding test images {} seconds **".format(time()-start_test))
# Out:
# Train images encoded  500
# Train images encoded  1000
# Train images encoded  1500
# Train images encoded  2000
# Train images encoded  2500
# Train images encoded  3000
# Train images encoded  3500
# Train images encoded  4000
# Train images encoded  4500
# Train images encoded  5000
# Train images encoded  5500
# Train images encoded  6000
# ** Time taken for encoding train images 450.39218831062317 seconds **
# Test images encoded  200
# Test images encoded  400
# Test images encoded  600
# Test images encoded  800
# Test images encoded  1000
# ** Time taken for encoding test images 79.75033593177795 seconds **

# %% [markdown]
# # Save the learned features

# %%
# # Save the bottleneck train features to disk
with open("encoded_train_images.pkl", "wb") as encoded_pickle:
    dump(encoding_train, encoded_pickle)
    
# # Save the bottleneck test features to disk
with open("encoded_test_images.pkl", "wb") as encoded_pickle:
    dump(encoding_test, encoded_pickle)

# %% [markdown]
# # All train captions (6000 x 5 = 30,000)

# %%
train_features = load(open("encoded_train_images.pkl", "rb"))

# Create a list of all the training captions
all_train_captions = []
for captions in train_captions.values():
    for caption in captions:
        all_train_captions.append(caption)
    
print(len(all_train_captions))
print(*all_train_captions[:10],sep='\n')
# Out:
# 30000
# startseq child in pink dress is climbing up set of stairs in an entry way endseq
# startseq girl going into wooden building endseq
# startseq little girl climbing into wooden playhouse endseq
# startseq little girl climbing the stairs to her playhouse endseq
# startseq little girl in pink dress going into wooden cabin endseq
# startseq black dog and spotted dog are fighting endseq
# startseq black dog and dog playing with each other on the road endseq
# startseq black dog and white dog with brown spots are staring at each other in the street endseq
# startseq two dogs of different breeds looking at each other on the road endseq
# startseq two dogs on pavement moving toward each other endseq

# %% [markdown]
# # Consider only those words which occur atleast 10 times in corpus

# %%
corpus = []
for caption in all_train_captions:
    for token in caption.split():
        corpus.append(token)
        
hash_map = Counter(corpus)
vocab = []
for token,count in hash_map.items():
    if(count>=10):
        vocab.append(token)
        
print('Number of original tokens',len(hash_map))
print('Number of tokens after threshold',len(vocab))
# Out:
# Number of original tokens 7265
# Number of tokens after threshold 1643

# %% [markdown]
# # Mapping: Index to words & Word to index

# %%
word_to_index = {}
index_to_word = {}
    
for idx,token in enumerate(vocab):
    word_to_index[token] = idx+1
    index_to_word[idx+1] = token

vocab_size = len(index_to_word) + 1 # one for appended 0's

print(len(index_to_word))
# Out:
# 1643

# %% [markdown]
# # Calculate max-length caption

# %%
def max_len_caption(all_train_captions):   
    max_len = 0
    for caption in all_train_captions:
        max_len = max(max_len,len(caption.split()))
    print('Maximum length of caption= ',max_len)
    return max_len

max_length_caption = max_len_caption(all_train_captions)
# Out:
# Maximum length of caption=  33

# %% [markdown]
# # Data Preparation using Generator Function

# %%
# data generator, intended to be used in a call to model.fit_generator()
def data_generator(descriptions, photos, wordtoix, max_length, num_photos_per_batch):
    X1, X2, y = list(), list(), list()
    n=0
    # loop for ever over images
    while 1:
        for key, desc_list in descriptions.items():
            n+=1
            # retrieve the photo feature
            temp='/content/Flicker8k_Dataset'
            
            photo = photos[temp+'/'+key+'.jpg']
            for desc in desc_list:
                # encode the sequence
                seq = [wordtoix[word] for word in desc.split(' ') if word in wordtoix]
                # split one sequence into multiple X, y pairs
                for i in range(1, len(seq)):
                    # split into input and output pair
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                    # encode output sequence
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    # store
                    X1.append(photo)
                    X2.append(in_seq)
                    y.append(out_seq)
            # yield the batch data
            if n==num_photos_per_batch:
                yield [[array(X1), array(X2)], array(y)]
                X1, X2, y = list(), list(), list()
                n=0

# %% [markdown]
# # Load GloVe vectors

# %%
embeddings_index = {} # empty dictionary
f = open('/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/glove.6B.200d.txt', encoding="utf-8")

for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
embedding_dim = 200

# Get 200-dim dense vector for each of the 10000 words in out vocabulary
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in word_to_index.items():
    #if i < max_words:
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # Words not found in the embedding index will be all zeros
        embedding_matrix[i] = embedding_vector
        
embedding_matrix.shape
# Out:
# (1644, 200)

# %%
inputs1 = Input(shape=(2048,))
fe1 = Dropout(0.5)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)
inputs2 = Input(shape=(max_length_caption,))
se1 = Embedding(vocab_size, embedding_dim, mask_zero=True)(inputs2)
se2 = Dropout(0.5)(se1)
se3 = LSTM(256)(se2)
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)
model = Model(inputs=[inputs1, inputs2], outputs=outputs)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 33)]         0           []
#
#  input_2 (InputLayer)           [(None, 2048)]       0           []
#
#  embedding (Embedding)          (None, 33, 200)      328800      ['input_3[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['input_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 33, 200)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 256)          524544      ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 256)          467968      ['dropout_1[0][0]']
#
#  add (Add)                      (None, 256)          0           ['dense[0][0]',
#                                                                   'lstm[0][0]']
#
#  dense_1 (Dense)                (None, 256)          65792       ['add[0][0]']
#
#  dense_2 (Dense)                (None, 1644)         422508      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1,809,612
# Trainable params: 1,809,612
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
print(model.layers[2])

model.layers[2].set_weights([embedding_matrix])
model.layers[2].trainable = False
# Out:
# <keras.layers.embeddings.Embedding object at 0x7fea40c60ed0>

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
epochs = 20
number_pics_per_bath = 3
steps = len(train_captions)//number_pics_per_bath

# %%
temp='/content/Flicker8k_Dataset'
temp
# Out:
# '/content/Flicker8k_Dataset'

# %%
for i in range(epochs):
    generator = data_generator(train_captions, train_features, word_to_index, max_length_caption, number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save('/content/model_weights/model_' + str(i) + '.h5')
# Image.open('training_1.PNG')
# Out:
# 2000/2000 [==============================] - 211s 103ms/step - loss: 4.1178
# 2000/2000 [==============================] - 213s 106ms/step - loss: 3.4204
# 2000/2000 [==============================] - 201s 101ms/step - loss: 3.2013
# 2000/2000 [==============================] - 202s 101ms/step - loss: 3.0698
# 2000/2000 [==============================] - 201s 101ms/step - loss: 2.9743
# 2000/2000 [==============================] - 203s 101ms/step - loss: 2.9058
# 2000/2000 [==============================] - 197s 99ms/step - loss: 2.8458
# 2000/2000 [==============================] - 200s 100ms/step - loss: 2.7981
# 2000/2000 [==============================] - 196s 98ms/step - loss: 2.7587
# 2000/2000 [==============================] - 198s 99ms/step - loss: 2.7231

# %%
import shutil
shutil.copy("/content/model_weights/model_9.h5", "/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/model_9.h5")
# Out:
# '/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/model_9.h5'

# %%
shutil.copy('/content/preprocessed_captions.txt','/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/preprocessed_captions.txt')
shutil.copy('/content/encoded_train_images.pkl','/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/encoded_train_images.pkl')
# Out:
# '/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/encoded_train_images.pkl'

# %%
shutil.copy('/content/Flickr_8k.trainImages.txt','/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/Flickr_8k.trainImages.txt')
# Out:
# '/content/drive/MyDrive/HTCGlobalServices/AutomaticImageCaptioning/Image_cap_ten/Flickr_8k.trainImages.txt'

# %%
# for i in range(epochs):
#     generator = data_generator(train_captions, train_features, word_to_index, max_length_caption, number_pics_per_bath)
#     model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
#     model.save('./model_weights/model_' + str(i) + '.h5')
Image.open('training_2.PNG')

# %%
model.optimizer.lr = 0.0001
epochs = 10
number_pics_per_bath = 6
steps = len(train_captions)//number_pics_per_bath

# for i in range(epochs):
#     generator = data_generator(train_captions, train_features, word_to_index, max_length_caption, number_pics_per_bath)
#     model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
#     #model.save('./model_weights/model_' + str(i) + '.h5')

Image.open('training_3.PNG')

# %%
# model.save_weights('./model_weights/model_30.h5')
# model.load_weights('./model_weights/model_30.h5')

images = ''
with open("encoded_test_images.pkl", "rb") as encoded_pickle:
    encoding_test = load(encoded_pickle)
    
def greedySearch(photo):
    in_text = 'startseq'
    for i in range(max_length_caption):
        sequence = [word_to_index[w] for w in in_text.split() if w in word_to_index]
        sequence = pad_sequences([sequence], maxlen=max_length_caption)
        yhat = model.predict([photo,sequence], verbose=0)
        yhat = np.argmax(yhat)
        word = index_to_word[yhat]
        in_text += ' ' + word
        if word == 'endseq':
            break
    final = in_text.split()
    final = final[1:-1]
    final = ' '.join(final)
    return final

# %%
z=11
pic = list(encoding_test.keys())[z]
image = encoding_test[pic].reshape((1,2048))
x=plt.imread(images+pic)
plt.imshow(x)
plt.show()
print("Greedy:",greedySearch(image))

# Image.open('inference.PNG')
# Out:
# Greedy: man in black shirt and leather cap is wearing black shirt

# %%
x=plt.imread('/content/Flicker8k_Dataset/1000268201_693b08cb0e.jpg')
plt.imshow(x)
plt.show()
print("Greedy:",greedySearch(image))
# Out:
# Greedy: man in black shirt and leather cap is wearing black shirt

# %%
# if __name__=='__main__':
    
#     # load all captions 
#     text = load_doc("Flickr8k_text/Flickr8k.token.txt") # list
#     for line in text[:10]:
#         print(line,end='')
    
#     # map image to captions in dictionary 
#     map_img_to_captions = image_to_captions(text) # dictionary (key:img name) (value-list of 5 captions)
#     print(*map_img_to_captions['1000268201_693b08cb0e'],sep='\n')
    
#     # preprocess captions
#     preprocessed_map = preprocess(map_img_to_captions) # dictionary (key:img name) (value-list of 5 preprocessed-captions)
#     print(preprocessed_map['1000268201_693b08cb0e'])

#     # prepare vocabulary from captions
#     vocabulary = create_vocabulary(preprocessed_map) # list
#     print('Vocabulary size',len(vocabulary))
    
#     # save image name with preprocessed captions in a new text file
#     filename = 'preprocessed_captions.txt'
#     save_captions(preprocessed_map,filename)
#     print('Saved image names with preprocessed captions in {}'.format(filename))
    
    
#     # load image name for train & test data
#     train_img_name = img_id_train('Flickr8k_text/Flickr_8k.trainImages.txt') # list
#     test_img_name  = img_id_train('Flickr8k_text/Flickr_8k.testImages.txt')  # list 
#     print('\nNumber of images in train data',len(train_img_name)) 
#     print('\nNumber of images in train data',len(test_img_name))
    
#     # load captions for train data and 'start_seq' and 'end_seq' in starting and end of each caption respectively
#     train_captions = load_captions_train('preprocessed_captions.txt')
#     print(*train_captions['1000268201_693b08cb0e'],sep='\n')
    
    
#     # image names for complete, train and test data
#     path = 'Flickr8k_Dataset/Flicker8k_Dataset/'
#     all_images_name = images_name(path)
#     train_img_name = [path+img+'.jpg' for img in train_img_name]
#     test_img_name = [path+img+'.jpg' for img in test_img_name]
    
    
#     # Load Inception-V3 model
#     model = InceptionV3(weights='imagenet')
#     # Create new model, by removing last layer (output layer) from Inception-V3
#     model_new = Model(inputs=model.input, outputs=model.layers[-2].output) # outputs=(second last layer output)
    
    
# #     # encode all train images
# #     start_train = time()
# #     encoding_train = {}
# #     for idx,img in enumerate(train_img_name):
# #         if( (idx+1)%500 == 0):
# #             print('Train images encoded ',idx+1)
# #         encoding_train[img] = encode_image(img)
# #     print("** Time taken for encoding train images {} seconds **".format(time()-start_train))


# #     # encode all test images
# #     start_test = time()
# #     encoding_test = {}
# #     for idx,img in enumerate(test_img_name):
# #         if( (idx+1)%200 == 0):
# #             print('Test images encoded ',idx+1)
# #         encoding_test[img] = encode_image(img)
# #     print("** Time taken for encoding test images {} seconds **".format(time()-start_test))
    
    
# # Save the bottleneck train features to disk
# #     with open("encoded_train_images.pkl", "wb") as encoded_pickle:
# #         dump(encoding_train, encoded_pickle)

# # Save the bottleneck test features to disk
# #     with open("encoded_test_images.pkl", "wb") as encoded_pickle:
# #         dump(encoding_test, encoded_pickle)
